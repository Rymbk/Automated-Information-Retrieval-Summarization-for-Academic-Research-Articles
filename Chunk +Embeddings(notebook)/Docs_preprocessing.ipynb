# %% [markdown]
# ---
# # Vector Database and RAG Setup
#
# <img src="https://miro.medium.com/v2/resize:fit:1400/0*kPXvR_-LxPfdsojc.png" width=600>
#
# Let's put it all together into a retrieval augmented generation flow:
# 1. Chunking text
# 2. Creating a Vector Database
# 3. Indexxing the text chunks
# 4. Setting up an LLM
# 5. Connecting retrieval with LLM for RAG

# %%
# RAG Dependencies
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
import chromadb
from langchain_openai import ChatOpenAI
from IPython.display import display, Markdown
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
import json
from sentence_transformers import SentenceTransformer

os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %% [markdown]
# ### Chunking the Text
#
# We'll be using the [TIES-Merging: Resolving Interference When Merging Models](https://arxiv.org/abs/2306.01708#) paper for our example, along with LangChain integrations with PDF loaders and chunkers.

# %%
# Paths
PDF_PATH = r"D:\2CSI-Project\PDFs_papers"  # Folder containing PDFs
CHUNKS_DIR = r"D:\2CSI-Project\Chunks"  # Folder to store chunks
PROGRESS_FILE = r"D:\2CSI-Project\progress.txt"  # File to save the last processed index
VECTORDB_PATH = r"D:\2CSI-Project\VectorDB_Embeddings"
EMBEDDING_MODEL = "all-MiniLM-L6-v2"
os.makedirs(CHUNKS_DIR, exist_ok=True)

# %%
client = chromadb.PersistentClient(path=VECTORDB_PATH)
collection = client.get_or_create_collection(name='ties_collection_emb', metadata={"hnsw:space": "cosine"})

# %%
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=800,
    chunk_overlap=400,
)

# %% [markdown]
# #  Read Last Progress

# %%
if os.path.exists(PROGRESS_FILE):
    with open(PROGRESS_FILE, "r") as f:
        last_index = int(f.read().strip())
else:
    last_index = 0

# %%
last_index
# Out:
# 0

# %% [markdown]
# # List Chunks

# %%
chunk_files = sorted(os.listdir(CHUNKS_DIR))
total_files = len(chunk_files)
if os.path.exists(PROGRESS_FILE):
    with open(PROGRESS_FILE, "r") as f:
        last_index = int(f.read().strip())
else:
    last_index = 0

print(f"Starting from file {last_index + 1}/{total_files}")
# Out:
# Starting from file 1/6158

# %% [markdown]
# #  Load Embedding Model

# %%
embedding_model = SentenceTransformer(EMBEDDING_MODEL)

# %%
for idx, chunk_file in enumerate(chunk_files):
    if idx < last_index:
        continue

    try:
        print(f"📄 Processing: {chunk_file} [{idx + 1}/{total_files}]")
        with open(os.path.join(CHUNKS_DIR, chunk_file), "r", encoding="utf-8") as f:
            chunks = json.load(f)

        # Generate Embeddings + Store in ChromaDB
        for i, chunk in enumerate(chunks):
            embedding = embedding_model.encode(chunk).tolist()
            collection.add(
                documents=[chunk],
                embeddings=[embedding],
                ids=[f"{chunk_file[:-11]}_chunk_{i}"]
            )

        print(f"✅ {len(chunks)} Chunks Indexed")

        # Update Progress
        with open(PROGRESS_FILE, "w") as f:
            f.write(str(idx + 1))

    except Exception as e:
        print(f"❌ Error processing {chunk_file}: {e}")
        continue

print("🚀 All Chunks Processed!")
# Out:
# 📄 Processing: $C^$-Algebraic Machine Learning Moving in a New Di_chunks.json [1/6158]
# ✅ 44 Chunks Indexed
# 📄 Processing: $E(2)$-Equivariant Vision Transformer_chunks.json [2/6158]
# ✅ 38 Chunks Indexed
# 📄 Processing: $mathrm{SAM^{Med}}$ A medical image annotation fra_chunks.json [3/6158]
# ✅ 38 Chunks Indexed
# 📄 Processing: 10_2263363_chunks.json [4/6158]
# ✅ 39 Chunks Indexed
# 📄 Processing: 11_1434678_chunks.json [5/6158]
# ✅ 181 Chunks Indexed
# 📄 Processing: 12_2202843_chunks.json [6/6158]
# ✅ 12 Chunks Indexed
# 📄 Processing: 13_4099100_chunks.json [7/6158]
# ✅ 102 Chunks Indexed
# 📄 Processing: 14_3224393_chunks.json [8/6158]
# ✅ 95 Chunks Indexed
# 📄 Processing: 15_1275662_chunks.json [9/6158]
# ✅ 30 Chunks Indexed
# 📄 Processing: 16_2846909_chunks.json [10/6158]
# ✅ 15 Chunks Indexed
# 📄 Processing: 17_2307352_chunks.json [11/6158]
# ✅ 86 Chunks Indexed
# 📄 Processing: 18_3489010_chunks.json [12/6158]
# ✅ 33 Chunks Indexed
# 📄 Processing: 1996--1998 Polish Visual Meteor Database_chunks.json [13/6158]
# ✅ 9 Chunks Indexed
# 📄 Processing: 19_2076397_chunks.json [14/6158]
# ✅ 43 Chunks Indexed
# 📄 Processing: 1_1926431_chunks.json [15/6158]
# ✅ 19 Chunks Indexed
# 📄 Processing: 1st Place in ICCV 2023 Workshop Challenge Track 1 _chunks.json [16/6158]
# ✅ 7 Chunks Indexed
# 📄 Processing: 20_3024938_chunks.json [17/6158]
# ✅ 138 Chunks Indexed
# 📄 Processing: 21_3970671_chunks.json [18/6158]
# ✅ 15 Chunks Indexed
# 📄 Processing: 22_3059856_chunks.json [19/6158]
# ✅ 91 Chunks Indexed
# 📄 Processing: 23_3484114_chunks.json [20/6158]
# ✅ 38 Chunks Indexed
# 📄 Processing: 2488552_chunks.json [21/6158]
# ✅ 42 Chunks Indexed
# 📄 Processing: 24_3289109_chunks.json [22/6158]
# ✅ 99 Chunks Indexed
# 📄 Processing: 2521007_chunks.json [23/6158]
# ✅ 41 Chunks Indexed
# 📄 Processing: 25_2765268_chunks.json [24/6158]
# ✅ 183 Chunks Indexed
# 📄 Processing: 26_1732598_chunks.json [25/6158]
# ✅ 29 Chunks Indexed
# 📄 Processing: 27_2727884_chunks.json [26/6158]
# ✅ 121 Chunks Indexed
# 📄 Processing: 28_3799204_chunks.json [27/6158]
# ✅ 41 Chunks Indexed
# 📄 Processing: 29_1909366_chunks.json [28/6158]
# ✅ 153 Chunks Indexed
# 📄 Processing: 2D and 3D CNN-Based Fusion Approach for COVID-19 S_chunks.json [29/6158]
# ✅ 13 Chunks Indexed
# 📄 Processing: 2_3123957_chunks.json [30/6158]
# ✅ 115 Chunks Indexed
# 📄 Processing: 2nd Place Solution to Facebook AI Image Similarity_chunks.json [31/6158]
# ✅ 4 Chunks Indexed
# 📄 Processing: 3- and 5-Isogenies of Supersingular Edwards Curves_chunks.json [32/6158]
# ✅ 50 Chunks Indexed
# 📄 Processing: 30_642863_chunks.json [33/6158]
# ✅ 81 Chunks Indexed
# 📄 Processing: 3146924_chunks.json [34/6158]
# ✅ 76 Chunks Indexed
# 📄 Processing: 31_3955789_chunks.json [35/6158]
# ✅ 35 Chunks Indexed
# 📄 Processing: 32_393042_chunks.json [36/6158]
# ✅ 49 Chunks Indexed
# 📄 Processing: 3330134_chunks.json [37/6158]
# ✅ 60 Chunks Indexed
# 📄 Processing: 33_4438593_chunks.json [38/6158]
# ✅ 79 Chunks Indexed
# 📄 Processing: 34_1461712_chunks.json [39/6158]
# ✅ 108 Chunks Indexed
# 📄 Processing: 35_955358_chunks.json [40/6158]
# ✅ 69 Chunks Indexed
# 📄 Processing: 36_2976428_chunks.json [41/6158]
# ✅ 35 Chunks Indexed
# 📄 Processing: 37_3963651_chunks.json [42/6158]
# ✅ 17 Chunks Indexed
# 📄 Processing: 3860262_chunks.json [43/6158]
# ✅ 133 Chunks Indexed
# 📄 Processing: 38_1612851_chunks.json [44/6158]
# ✅ 187 Chunks Indexed
# 📄 Processing: 39_3323796_chunks.json [45/6158]
# ✅ 29 Chunks Indexed
# 📄 Processing: 3D Foundation AI Model for Generalizable Disease D_chunks.json [46/6158]
# ✅ 65 Chunks Indexed
# 📄 Processing: 3D-MoE A Mixture-of-Experts Multi-modal LLM for 3D_chunks.json [47/6158]
# ✅ 23 Chunks Indexed
# 📄 Processing: 3D-OOCS Learning Prostate Segmentation with Induct_chunks.json [48/6158]
# ✅ 20 Chunks Indexed
# 📄 Processing: 3P-LLM Probabilistic Path Planning using Large Lan_chunks.json [49/6158]
# ✅ 17 Chunks Indexed
# 📄 Processing: 3_3258234_chunks.json [50/6158]
# ✅ 66 Chunks Indexed
# 📄 Processing: 40_568165_chunks.json [51/6158]
# ✅ 37 Chunks Indexed
# 📄 Processing: 41_1108671_chunks.json [52/6158]
# ✅ 6 Chunks Indexed
# 📄 Processing: 42_3146191_chunks.json [53/6158]
# ✅ 21 Chunks Indexed
# 📄 Processing: 43_3953589_chunks.json [54/6158]
# ✅ 5 Chunks Indexed
# 📄 Processing: 44_2972855_chunks.json [55/6158]
# ✅ 139 Chunks Indexed
# 📄 Processing: 45_4217148_chunks.json [56/6158]
# ✅ 147 Chunks Indexed
# 📄 Processing: 46_2152421_chunks.json [57/6158]
# ✅ 13 Chunks Indexed
# 📄 Processing: 47_2907744_chunks.json [58/6158]
# ✅ 7 Chunks Indexed
# 📄 Processing: 48_3954600_chunks.json [59/6158]
# ✅ 14 Chunks Indexed
# 📄 Processing: 49_2216866_chunks.json [60/6158]
# ✅ 130 Chunks Indexed
# 📄 Processing: 4C A Computation, Communication, and Control Co-De_chunks.json [61/6158]
# ✅ 23 Chunks Indexed
# 📄 Processing: 4_1078740_chunks.json [62/6158]
# ✅ 93 Chunks Indexed
# 📄 Processing: 50_3164973_chunks.json [63/6158]
# ✅ 120 Chunks Indexed
# 📄 Processing: 5_504062_chunks.json [64/6158]
# ✅ 19 Chunks Indexed
# 📄 Processing: 61A Bot Report AI Assistants in CS1 Save Students _chunks.json [65/6158]
# ✅ 28 Chunks Indexed
# 📄 Processing: 680Development and evaluation of return calls  a_2018_chunks.json [66/6158]
# ✅ 4 Chunks Indexed
# 📄 Processing: 6G Communication Technology A Vision on Intelligen_chunks.json [67/6158]
# ✅ 35 Chunks Indexed
# 📄 Processing: 6_3955546_chunks.json [68/6158]
# ✅ 27 Chunks Indexed
# 📄 Processing: 70 years of machine learning in geoscience in revi_chunks.json [69/6158]
# ✅ 94 Chunks Indexed
# 📄 Processing: 7_2401352_chunks.json [70/6158]
# ✅ 143 Chunks Indexed
# 📄 Processing: 8_3265913_chunks.json [71/6158]
# ✅ 40 Chunks Indexed
# 📄 Processing: 9_3438276_chunks.json [72/6158]
# ✅ 37 Chunks Indexed
# 📄 Processing: A 35-Year Longitudinal Analysis of Dermatology Pat_chunks.json [73/6158]
# ✅ 21 Chunks Indexed
# 📄 Processing: A Bayesian Method for Constructing Bayesian Belief_chunks.json [74/6158]
# ✅ 28 Chunks Indexed
# 📄 Processing: A Bayesian View of the Poisson-Dirichlet Process_chunks.json [75/6158]
# ✅ 89 Chunks Indexed
# 📄 Processing: A Bayesian algorithm for detecting identity matche_chunks.json [76/6158]
# ✅ 14 Chunks Indexed
# 📄 Processing: A Benchmark Study by using various Machine Learnin_chunks.json [77/6158]
# ✅ 41 Chunks Indexed
# 📄 Processing: A Benchmark Study of Deep-RL Methods for Maximum C_chunks.json [78/6158]
# ✅ 69 Chunks Indexed
# 📄 Processing: A Benchmark and Evaluation of Non-Rigid Structure _chunks.json [79/6158]
# ✅ 60 Chunks Indexed
# 📄 Processing: A Benchmark for Federated Hetero-Task Learning_2022_chunks.json [80/6158]
# ✅ 39 Chunks Indexed
# 📄 Processing: A Bi-Level Stochastic Game Model for PMU Placement_chunks.json [81/6158]
# ✅ 24 Chunks Indexed
# 📄 Processing: A Bibliometric Analysis of Blockchain Technology R_2022_chunks.json [82/6158]
# ✅ 34 Chunks Indexed
# 📄 Processing: A Bibliometric View of AI Ethics Development_chunks.json [83/6158]
# ✅ 10 Chunks Indexed
# 📄 Processing: A Big Data Approach to Computational Creativity_chunks.json [84/6158]
# ✅ 34 Chunks Indexed
# 📄 Processing: A Big Data Architecture for Log Data Storage and A_chunks.json [85/6158]
# ✅ 6 Chunks Indexed
# 📄 Processing: A Big Data Lake for Multilevel Streaming Analytics_chunks.json [86/6158]
# ✅ 22 Chunks Indexed
# 📄 Processing: A Big data analytical framework for portfolio opti_chunks.json [87/6158]
# ✅ 9 Chunks Indexed
# 📄 Processing: A Biologically Inspired Classifier_chunks.json [88/6158]
# ✅ 11 Chunks Indexed
# 📄 Processing: A Blink Tree latch method and protocol to support _chunks.json [89/6158]
# ✅ 8 Chunks Indexed
# 📄 Processing: A Blockchain Framework for Patient-Centered Health_2019_chunks.json [90/6158]
# ✅ 74 Chunks Indexed
# 📄 Processing: A Blockchain-Enabled Approach to Cross-Border Comp_chunks.json [91/6158]
# ✅ 28 Chunks Indexed
# 📄 Processing: A Brief Introduction to Causal Inference in Machin_chunks.json [92/6158]
# ✅ 132 Chunks Indexed
# 📄 Processing: A Brief Review of Deep Multi-task Learning and Aux_chunks.json [93/6158]
# ✅ 11 Chunks Indexed
# 📄 Processing: A Brief Review of Hypernetworks in Deep Learning_chunks.json [94/6158]
# ✅ 55 Chunks Indexed
# 📄 Processing: A Brief Survey of Deep Reinforcement Learning_chunks.json [95/6158]
# ✅ 68 Chunks Indexed
# 📄 Processing: A C++ library for Multimodal Deep Learning_chunks.json [96/6158]
# ✅ 42 Chunks Indexed
# 📄 Processing: A Close Look into Human Activity Recognition Model_chunks.json [97/6158]
# ✅ 16 Chunks Indexed
# 📄 Processing: A Closer Look at Variance Implementations in Moder_chunks.json [98/6158]
# ✅ 33 Chunks Indexed
# 📄 Processing: A Clustering Strategy for Enhanced FL-Based Intrus_chunks.json [99/6158]
# ✅ 25 Chunks Indexed
# 📄 Processing: A Cognitive and Machine Learning-Based Software De_chunks.json [100/6158]
# ✅ 14 Chunks Indexed
# 📄 Processing: A Cold Flare With Delayed Heating_chunks.json [101/6158]
# ✅ 75 Chunks Indexed
# 📄 Processing: A Collaborative Filtering-Based Two Stage Model wi_2017_chunks.json [102/6158]
# ✅ 25 Chunks Indexed
# 📄 Processing: A Comparative Analysis Between SciTokens, Verifiab_chunks.json [103/6158]
# ✅ 15 Chunks Indexed
# 📄 Processing: A Comparative Analysis of Machine Learning and Gre_chunks.json [104/6158]
# ✅ 82 Chunks Indexed
# 📄 Processing: A Comparative Analysis of Port Scanning Tool Effic_chunks.json [105/6158]
# ✅ 21 Chunks Indexed
# 📄 Processing: A Comparative Approach to Explainable Artificial I_chunks.json [106/6158]
# ✅ 24 Chunks Indexed
# 📄 Processing: A Comparative Study Blockchain Technology Utiliza_2021_chunks.json [107/6158]
# ✅ 77 Chunks Indexed
# 📄 Processing: A Comparative Study of Pre-trained CNNs and GRU-Ba_chunks.json [108/6158]
# ✅ 32 Chunks Indexed
# 📄 Processing: A Comparative Survey of Recent Natural Language In_chunks.json [109/6158]
# ✅ 91 Chunks Indexed
# 📄 Processing: A Comparison of Big Data Frameworks on a Layered D_chunks.json [110/6158]
# ✅ 30 Chunks Indexed
# 📄 Processing: A Comparison of Different Models of Glycemia Dynam_2020_chunks.json [111/6158]
# ✅ 41 Chunks Indexed
# 📄 Processing: A Comparison of First-order Algorithms for Machine_chunks.json [112/6158]
# ✅ 17 Chunks Indexed
# 📄 Processing: A Comparison of Machine Learning Methods for Data _chunks.json [113/6158]
# ✅ 17 Chunks Indexed
# 📄 Processing: A Comparison of Microbial Genome Web Portals_chunks.json [114/6158]
# ✅ 39 Chunks Indexed
# 📄 Processing: A Comprehensive Analysis of Deep Learning Based Re_chunks.json [115/6158]
# ✅ 25 Chunks Indexed
# 📄 Processing: A Comprehensive Overview and Comparative Analysis _chunks.json [116/6158]
# ✅ 141 Chunks Indexed
# 📄 Processing: A Comprehensive Overview and Survey of Recent Adva_chunks.json [117/6158]
# ✅ 146 Chunks Indexed
# 📄 Processing: A Comprehensive Python Library for Deep Learning-B_chunks.json [118/6158]
# ✅ 18 Chunks Indexed
# 📄 Processing: A Comprehensive Review of Knowledge Distillation i_chunks.json [119/6158]
# ✅ 85 Chunks Indexed
# 📄 Processing: A Comprehensive Review of State-of-The-Art Methods_chunks.json [120/6158]
# ✅ 68 Chunks Indexed
# 📄 Processing: A Comprehensive Review on Computer Vision Analysis_chunks.json [121/6158]
# ✅ 182 Chunks Indexed
# 📄 Processing: A Comprehensive Review on Deep Supervision Theorie_chunks.json [122/6158]
# ✅ 57 Chunks Indexed
# 📄 Processing: A Comprehensive Study of Vision Transformers on De_chunks.json [123/6158]
# ✅ 32 Chunks Indexed
# 📄 Processing: A Comprehensive Study on Deep Learning Bug Charact_chunks.json [124/6158]
# ✅ 42 Chunks Indexed
# 📄 Processing: A Comprehensive Survey of Attack Techniques, Imple_chunks.json [125/6158]
# ✅ 41 Chunks Indexed
# 📄 Processing: A Comprehensive Survey of Natural Language Generat_chunks.json [126/6158]
# ✅ 210 Chunks Indexed
# 📄 Processing: A Comprehensive Survey on Deep Clustering Taxonomy_chunks.json [127/6158]
# ✅ 100 Chunks Indexed
# 📄 Processing: A Comprehensive Survey on Deep Learning Techniques_chunks.json [128/6158]
# ✅ 88 Chunks Indexed
# 📄 Processing: A Comprehensive Survey on Machine Learning-Based B_2021_chunks.json [129/6158]
# ✅ 55 Chunks Indexed
# 📄 Processing: A Comprehensive Survey with Critical Analysis for _chunks.json [130/6158]
# ✅ 110 Chunks Indexed
# 📄 Processing: A Computational Model for Ransomware Detection Usi_chunks.json [131/6158]
# ✅ 24 Chunks Indexed
# 📄 Processing: A Concept Specification and Abstraction-based Sema_chunks.json [132/6158]
# ✅ 41 Chunks Indexed
# 📄 Processing: A Conjecture about a vision model for blind men_chunks.json [133/6158]
# ✅ 4 Chunks Indexed
# 📄 Processing: A Consolidated Online Database of Galactic Planeta_chunks.json [134/6158]
# ✅ 4 Chunks Indexed
# 📄 Processing: A Constrained Shortest Path Scheme for Virtual Net_chunks.json [135/6158]
# ✅ 72 Chunks Indexed
# 📄 Processing: A Constraint Programming Approach for Mining Seque_chunks.json [136/6158]
# ✅ 25 Chunks Indexed
# 📄 Processing: A Contemporary Survey of Large Language Model Assi_chunks.json [137/6158]
# ✅ 85 Chunks Indexed
# 📄 Processing: A Continual Learning Survey Defying Forgetting in_2019_chunks.json [138/6158]
# ✅ 91 Chunks Indexed
# 📄 Processing: A Controlled Experiment on the Impact of Intrusion_chunks.json [139/6158]
# ✅ 17 Chunks Indexed
# 📄 Processing: A Coordination Language for Databases_chunks.json [140/6158]
# ✅ 136 Chunks Indexed
# 📄 Processing: A Copernican Revolution in Data_chunks.json [141/6158]
# ✅ 7 Chunks Indexed
# 📄 Processing: A Critical Review of Blockchain Acceptance Models _2022_chunks.json [142/6158]
# ✅ 88 Chunks Indexed
# 📄 Processing: A Critique of the CAP Theorem_chunks.json [143/6158]
# ✅ 40 Chunks Indexed
# 📄 Processing: A Cutting-Edge Deep Learning Method For Enhancing _chunks.json [144/6158]
# ✅ 17 Chunks Indexed
# 📄 Processing: A Cyberattack Detection-Isolation Scheme For CAV U_chunks.json [145/6158]
# ✅ 50 Chunks Indexed
# 📄 Processing: A DECENTRALIZED AUTONOMOUS SYSTEM USING A BLOCKCHA_2024_chunks.json [146/6158]
# ✅ 21 Chunks Indexed
# 📄 Processing: A Data-Centric Methodology and Task Typology for T_chunks.json [147/6158]
# ✅ 50 Chunks Indexed
# 📄 Processing: A Data-Driven Approach to Full-Field Damage and Fa_chunks.json [148/6158]
# ✅ 39 Chunks Indexed
# 📄 Processing: A Database Engineered System for Big Data Analytic_chunks.json [149/6158]
# ✅ 23 Chunks Indexed
# 📄 Processing: A Database Watermarking Service with a Trusted Aut_2013_chunks.json [150/6158]
# ✅ 28 Chunks Indexed
# 📄 Processing: A Database of 2,500 Quasicrystal Cells_chunks.json [151/6158]
# ✅ 13 Chunks Indexed
# 📄 Processing: A Database of Belyi Maps_chunks.json [152/6158]
# ✅ 44 Chunks Indexed
# 📄 Processing: A Database of COBE-Normalized CDM Simulations (Abb_chunks.json [153/6158]
# ✅ 74 Chunks Indexed
# 📄 Processing: A Database of Ultrastable MOFs Reassembled from St_chunks.json [154/6158]
# ✅ 54 Chunks Indexed
# 📄 Processing: A Decentralized Reinforcement Learning Framework f_chunks.json [155/6158]
# ✅ 36 Chunks Indexed
# 📄 Processing: A Declarative Query Language for Scientific Machin_chunks.json [156/6158]
# ✅ 51 Chunks Indexed
# 📄 Processing: A Declarative System for Optimizing AI Workloads_chunks.json [157/6158]
# ✅ 90 Chunks Indexed
# 📄 Processing: A Deep Convolutional Auto-Encoder with Pooling - U_chunks.json [158/6158]
# ✅ 59 Chunks Indexed
# 📄 Processing: A Deep Hybrid Model for Recommendation Systems_chunks.json [159/6158]
# ✅ 23 Chunks Indexed
# 📄 Processing: A Deep Investigation of Deep IR Models_chunks.json [160/6158]
# ✅ 26 Chunks Indexed
# 📄 Processing: A Deep Learning Approach for Ontology Enrichment f_chunks.json [161/6158]
# ✅ 29 Chunks Indexed
# 📄 Processing: A Deep Learning Approach for Overall Survival Pred_chunks.json [162/6158]
# ✅ 32 Chunks Indexed
# 📄 Processing: A Deep Learning Approach for Predicting Spatiotemp_chunks.json [163/6158]
# ✅ 37 Chunks Indexed
# 📄 Processing: A Deep Learning Approach to Create DNS Amplificati_chunks.json [164/6158]
# ✅ 23 Chunks Indexed
# 📄 Processing: A Deep Learning Perspective on Connected Automated_chunks.json [165/6158]
# ✅ 41 Chunks Indexed
# 📄 Processing: A Deep Neural Network to identify foreshocks in re_chunks.json [166/6158]
# ✅ 9 Chunks Indexed
# 📄 Processing: A Deep Reinforcement Learning Approach for Composi_chunks.json [167/6158]
# ✅ 49 Chunks Indexed
# 📄 Processing: A Deep-Genetic Algorithm (Deep-GA) Approach for Hi_chunks.json [168/6158]
# ✅ 32 Chunks Indexed
# 📄 Processing: A Dictionary-based Approach to Racism Detection in_chunks.json [169/6158]
# ✅ 23 Chunks Indexed
# 📄 Processing: A Differentiable Physics Engine for Deep Learning _chunks.json [170/6158]
# ✅ 28 Chunks Indexed
# 📄 Processing: A Distributed Deep Representation Learning Model f_chunks.json [171/6158]
# ✅ 28 Chunks Indexed
# 📄 Processing: A Distributed Framework for Scalable Search over E_chunks.json [172/6158]
# ✅ 54 Chunks Indexed
# 📄 Processing: A Diversity-based Substation Cyber Defense Strateg_chunks.json [173/6158]
# ✅ 35 Chunks Indexed
# 📄 Processing: A Dynamic 3D Spontaneous Micro-expression Database_chunks.json [174/6158]
# ✅ 54 Chunks Indexed
# 📄 Processing: A Falsificationist Account of Artificial Neural Ne_chunks.json [175/6158]
# ✅ 48 Chunks Indexed
# 📄 Processing: A Family of Mixture Models for Biclustering_chunks.json [176/6158]
# ✅ 57 Chunks Indexed
# 📄 Processing: A Fast Converging and Globally Optimized Approach _2023_chunks.json [177/6158]
# ✅ 46 Chunks Indexed
# 📄 Processing: A Fast Partial Video Copy Detection Using KNN and _chunks.json [178/6158]
# ✅ 28 Chunks Indexed
# 📄 Processing: A Feature Selection Based on Perturbation Theory_chunks.json [179/6158]
# ✅ 35 Chunks Indexed
# 📄 Processing: A First Look at Deep Learning Apps on Smartphones_chunks.json [180/6158]
# ✅ 52 Chunks Indexed
# 📄 Processing: A First Look at SVCB and HTTPS DNS Resource Record_chunks.json [181/6158]
# ✅ 19 Chunks Indexed
# 📄 Processing: A First Step Towards Understanding Real-world Atta_chunks.json [182/6158]
# ✅ 24 Chunks Indexed
# 📄 Processing: A Flexible and Modular Architecture for Edge Digit_2022_chunks.json [183/6158]
# ✅ 74 Chunks Indexed
# 📄 Processing: A Formal Definition for Configuration_chunks.json [184/6158]
# ✅ 18 Chunks Indexed
# 📄 Processing: A Formal Verification of a Reputation Multi-Factor_2023_chunks.json [185/6158]
# ✅ 83 Chunks Indexed
# 📄 Processing: A Framework for Bottom-Up Simulation of SLD-Resolu_chunks.json [186/6158]
# ✅ 24 Chunks Indexed
# 📄 Processing: A Framework for Data Privacy Preserving in Supply _2023_chunks.json [187/6158]
# ✅ 64 Chunks Indexed
# 📄 Processing: A Framework for Distributed Deep Learning Layer De_chunks.json [188/6158]
# ✅ 22 Chunks Indexed
# 📄 Processing: A Framework for Fairer Machine Learning in Organiz_chunks.json [189/6158]
# ✅ 40 Chunks Indexed
# 📄 Processing: A Framework for Fine-Tuning LLMs using Heterogeneo_chunks.json [190/6158]
# ✅ 17 Chunks Indexed
# 📄 Processing: A Framework for High-throughput Sequence Alignment_chunks.json [191/6158]
# ✅ 38 Chunks Indexed
# 📄 Processing: A Framework for Implementing Machine Learning on O_chunks.json [192/6158]
# ✅ 9 Chunks Indexed
# 📄 Processing: A Fully-Automatic Framework for Parkinson's Diseas_chunks.json [193/6158]
# ✅ 19 Chunks Indexed
# 📄 Processing: A GPU based single-pulse search pipeline (GSP) wit_chunks.json [194/6158]
# ✅ 21 Chunks Indexed
# 📄 Processing: A GPU-accelerated Molecular Docking Workflow with _chunks.json [195/6158]
# ✅ 23 Chunks Indexed
# 📄 Processing: A Game Interface to Study Semantic Grounding in Te_chunks.json [196/6158]
# ✅ 15 Chunks Indexed
# 📄 Processing: A Game Theoretical vulnerability analysis of Adver_chunks.json [197/6158]
# ✅ 20 Chunks Indexed
# 📄 Processing: A Game of Dice Machine Learning and the Question C_chunks.json [198/6158]
# ✅ 5 Chunks Indexed
# 📄 Processing: A Game of Surface Codes Large-Scale Quantum Compu_2018_chunks.json [199/6158]
# ✅ 103 Chunks Indexed
# 📄 Processing: A General Framework for Anytime Approximation in P_chunks.json [200/6158]
# ✅ 8 Chunks Indexed
# 📄 Processing: A General Recipe for Contractive Graph Neural Netw_chunks.json [201/6158]
# ✅ 13 Chunks Indexed
# 📄 Processing: A General-Purpose Multimodal Foundation Model for _chunks.json [202/6158]
# ✅ 134 Chunks Indexed
# 📄 Processing: A Generalizable Artificial Intelligence Model for _chunks.json [203/6158]
# ✅ 21 Chunks Indexed
# 📄 Processing: A Generalized Occupation Time Formula For Continuo_chunks.json [204/6158]
# ✅ 5 Chunks Indexed
# 📄 Processing: A Generative Restricted Boltzmann Machine Based Me_chunks.json [205/6158]
# ✅ 35 Chunks Indexed
# 📄 Processing: A Grammar Formalism and Cross-Serial Dependencies_chunks.json [206/6158]
# ✅ 52 Chunks Indexed
# 📄 Processing: A Graph Feature Auto-Encoder for the Prediction of_chunks.json [207/6158]
# ✅ 28 Chunks Indexed
# 📄 Processing: A GraphBLAS Approach for Subgraph Counting_chunks.json [208/6158]
# ✅ 45 Chunks Indexed
# 📄 Processing: A Gray Box Interpretable Visual Debugging Approach_chunks.json [209/6158]
# ✅ 15 Chunks Indexed
# 📄 Processing: A Hierarchical Distributed Processing Framework fo_chunks.json [210/6158]
# ✅ 46 Chunks Indexed
# 📄 Processing: A Hierarchy of Limitations in Machine Learning_chunks.json [211/6158]
# ✅ 156 Chunks Indexed
# 📄 Processing: A High Performance Memory Database for Web Applica_chunks.json [212/6158]
# ✅ 18 Chunks Indexed
# 📄 Processing: A Higher-Order Generalized Singular Value Decompos_chunks.json [213/6158]
# ✅ 60 Chunks Indexed
# 📄 Processing: A Hybrid Deep Learning Anomaly Detection Framework_chunks.json [214/6158]
# ✅ 22 Chunks Indexed
# 📄 Processing: A Hybrid Deep Learning Classification of Perimetri_chunks.json [215/6158]
# ✅ 20 Chunks Indexed
# 📄 Processing: A Hybrid Evolutionary System for Automated Artific_chunks.json [216/6158]
# ✅ 63 Chunks Indexed
# 📄 Processing: A Hybrid Method for Traffic Flow Forecasting Using_chunks.json [217/6158]
# ✅ 39 Chunks Indexed
# 📄 Processing: A Jailbroken GenAI Model Can Cause Substantial Har_chunks.json [218/6158]
# ✅ 55 Chunks Indexed
# 📄 Processing: A KInetic Database for Astrochemistry (KIDA)_chunks.json [219/6158]
# ✅ 58 Chunks Indexed
# 📄 Processing: A Kernel for Hierarchical Parameter Spaces_chunks.json [220/6158]
# ✅ 15 Chunks Indexed
# 📄 Processing: A Knowledge Graph-Enhanced Tensor Factorisation Mo_chunks.json [221/6158]
# ✅ 36 Chunks Indexed
# 📄 Processing: A Large-Scale Database for Graph Representation Le_chunks.json [222/6158]
# ✅ 35 Chunks Indexed
# 📄 Processing: A Large-scale Medical Visual Task Adaptation Bench_chunks.json [223/6158]
# ✅ 43 Chunks Indexed
# 📄 Processing: A Learning Algorithm based on High School Teaching_chunks.json [224/6158]
# ✅ 32 Chunks Indexed
# 📄 Processing: A Learning Algorithm for Relational Logistic Regre_chunks.json [225/6158]
# ✅ 23 Chunks Indexed
# 📄 Processing: A Lexical Analysis Tool with Ambiguity Support_chunks.json [226/6158]
# ✅ 12 Chunks Indexed
# 📄 Processing: A Lexical Semantic Database for Verbmobil_chunks.json [227/6158]
# ✅ 18 Chunks Indexed
# 📄 Processing: A Linguistic Comparison between Human and ChatGPT-_chunks.json [228/6158]
# ✅ 28 Chunks Indexed
# 📄 Processing: A Literature Review on New Robotics Automation fr_2015_chunks.json [229/6158]
# ✅ 70 Chunks Indexed
# 📄 Processing: A Log-Linear Non-Parametric Online Changepoint Det_chunks.json [230/6158]
# ✅ 45 Chunks Indexed
# 📄 Processing: A Logic-Based Framework Leveraging Neural Networks_chunks.json [231/6158]
# ✅ 93 Chunks Indexed
# 📄 Processing: A Low Dimensional Approximation For Competence In _chunks.json [232/6158]
# ✅ 36 Chunks Indexed
# 📄 Processing: A Low-cost, High-impact Node Injection Approach fo_chunks.json [233/6158]
# ✅ 80 Chunks Indexed
# 📄 Processing: A Machine Learning Application for Raising WASH Aw_chunks.json [234/6158]
# ✅ 18 Chunks Indexed
# 📄 Processing: A Machine Learning Approach to Routing_chunks.json [235/6158]
# ✅ 28 Chunks Indexed
# 📄 Processing: A Machine Learning Tutorial for Operational Meteor_chunks.json [236/6158]
# ✅ 73 Chunks Indexed
# 📄 Processing: A Mathematical Abstraction for Balancing the Trade_chunks.json [237/6158]
# ✅ 79 Chunks Indexed
# 📄 Processing: A Meta-Method for Portfolio Management Using Machi_chunks.json [238/6158]
# ✅ 18 Chunks Indexed
# 📄 Processing: A Meta-Theory of Boundary Detection Benchmarks_chunks.json [239/6158]
# ✅ 9 Chunks Indexed
# 📄 Processing: A Meta-graph Approach to Analyze Subgraph-centric _chunks.json [240/6158]
# ✅ 41 Chunks Indexed
# 📄 Processing: A Method for Application of a Quantum Search Algor_chunks.json [241/6158]
# ✅ 33 Chunks Indexed
# 📄 Processing: A Method for Decrypting Data Infected with Rhysida_chunks.json [242/6158]
# ✅ 20 Chunks Indexed
# 📄 Processing: A Method for Implementing a Probabilistic Model as_chunks.json [243/6158]
# ✅ 30 Chunks Indexed
# 📄 Processing: A Methodology Based on Computational Patterns for _2020_chunks.json [244/6158]
# ✅ 21 Chunks Indexed
# 📄 Processing: A Methodology to Support Automatic Cyber Risk Asse_chunks.json [245/6158]
# ✅ 24 Chunks Indexed
# 📄 Processing: A Minimal Variance Estimator for the Cardinality o_chunks.json [246/6158]
# ✅ 40 Chunks Indexed
# 📄 Processing: A Model of Metallicity Evolution in the Early Univ_chunks.json [247/6158]
# ✅ 16 Chunks Indexed
# 📄 Processing: A Modular Benchmarking Infrastructure for High-Per_chunks.json [248/6158]
# ✅ 59 Chunks Indexed
# 📄 Processing: A Modular Open Source Framework for Genomic Varian_chunks.json [249/6158]
# ✅ 11 Chunks Indexed
# 📄 Processing: A Modular Quantum Compilation Framework for Distri_2023_chunks.json [250/6158]
# ✅ 38 Chunks Indexed
# 📄 Processing: A Multi-Center Study on the Adaptability of a Shar_chunks.json [251/6158]
# ✅ 67 Chunks Indexed
# 📄 Processing: A Multi-Client Searchable Encryption Scheme for Io_chunks.json [252/6158]
# ✅ 43 Chunks Indexed
# 📄 Processing: A Multi-Modal Graph-Based Semi-Supervised Pipeline_chunks.json [253/6158]
# ✅ 20 Chunks Indexed
# 📄 Processing: A Multi-Objective Deep Reinforcement Learning Fram_chunks.json [254/6158]
# ✅ 33 Chunks Indexed
# 📄 Processing: A Multi-cascaded Deep Model for Bilingual SMS Clas_chunks.json [255/6158]
# ✅ 26 Chunks Indexed
# 📄 Processing: A Multidisciplinary Approach to Telegram Data Anal_chunks.json [256/6158]
# ✅ 9 Chunks Indexed
# 📄 Processing: A Multimodal Automated Interpretability Agent_chunks.json [257/6158]
# ✅ 67 Chunks Indexed
# 📄 Processing: A Mutation-based Text Generation for Adversarial M_chunks.json [258/6158]
# ✅ 25 Chunks Indexed
# 📄 Processing: A Natural Language Interface with Relayed Acoustic_chunks.json [259/6158]
# ✅ 17 Chunks Indexed
# 📄 Processing: A Nesterov's Accelerated quasi-Newton method for G_chunks.json [260/6158]
# ✅ 13 Chunks Indexed
# 📄 Processing: A Neural Question Answering System for Basic Quest_chunks.json [261/6158]
# ✅ 44 Chunks Indexed
# 📄 Processing: A New Approach for Resource Scheduling with Deep R_chunks.json [262/6158]
# ✅ 17 Chunks Indexed
# 📄 Processing: A New Gene Selection Algorithm using Fuzzy-Rough S_chunks.json [263/6158]
# ✅ 53 Chunks Indexed
# 📄 Processing: A New Lightweight Algorithm to compute the BWT and_chunks.json [264/6158]
# ✅ 34 Chunks Indexed
# 📄 Processing: A New Method for Cross-Lingual-based Semantic Role_chunks.json [265/6158]
# ✅ 31 Chunks Indexed
# 📄 Processing: A New Pairwise Deep Learning Feature For Environme_chunks.json [266/6158]
# ✅ 36 Chunks Indexed
# 📄 Processing: A New Paradigm for Fault-Tolerant Computing with I_chunks.json [267/6158]
# ✅ 17 Chunks Indexed
# 📄 Processing: A New Perspective on ADHD Research Knowledge Graph_chunks.json [268/6158]
# ✅ 20 Chunks Indexed
# 📄 Processing: A New Perspective on Machine Learning How to do Pe_chunks.json [269/6158]
# ✅ 35 Chunks Indexed
# 📄 Processing: A New Perspective on Time Series Anomaly Detection_chunks.json [270/6158]
# ✅ 46 Chunks Indexed
# 📄 Processing: A New Technique to Backup and Restore DBMS using X_chunks.json [271/6158]
# ✅ 19 Chunks Indexed
# 📄 Processing: A New Type of Foundation Model Based on Recordings_chunks.json [272/6158]
# ✅ 21 Chunks Indexed
# 📄 Processing: A Note on Connectivity of Sublevel Sets in Deep Le_chunks.json [273/6158]
# ✅ 11 Chunks Indexed
# 📄 Processing: A Note on Kaldi's PLDA Implementation_chunks.json [274/6158]
# ✅ 4 Chunks Indexed
# 📄 Processing: A Novel AI-enabled Framework to Diagnose Coronavir_chunks.json [275/6158]
# ✅ 19 Chunks Indexed
# 📄 Processing: A Novel Adaptive Hybrid Focal-Entropy Loss for Enh_chunks.json [276/6158]
# ✅ 21 Chunks Indexed
# 📄 Processing: A Novel Approach for Image Segmentation based on H_chunks.json [277/6158]
# ✅ 6 Chunks Indexed
# 📄 Processing: A Novel Approach to Network Traffic Analysis the H_chunks.json [278/6158]
# ✅ 25 Chunks Indexed
# 📄 Processing: A Novel Approach to Quantum Heuristics for Structu_chunks.json [279/6158]
# ✅ 21 Chunks Indexed
# 📄 Processing: A Novel Buffered Federated Learning Framework for _chunks.json [280/6158]
# ✅ 21 Chunks Indexed
# 📄 Processing: A Novel Combinatorial Method for Estimating Transc_chunks.json [281/6158]
# ✅ 30 Chunks Indexed
# 📄 Processing: A Novel Deep Learning based Model to Defend Networ_chunks.json [282/6158]
# ✅ 24 Chunks Indexed
# 📄 Processing: A Novel Deep Reinforcement Learning Based Stock Di_chunks.json [283/6158]
# ✅ 24 Chunks Indexed
# 📄 Processing: A Novel Dialect-Aware Framework for the Classifica_chunks.json [284/6158]
# ✅ 29 Chunks Indexed
# 📄 Processing: A Novel Ensemble-Based Deep Learning Model with Ex_chunks.json [285/6158]
# ✅ 36 Chunks Indexed
# 📄 Processing: A Novel Feature Descriptor for Image Retrieval by _chunks.json [286/6158]
# ✅ 44 Chunks Indexed
# 📄 Processing: A Novel Framework Integrating AI Model and Enzymol_chunks.json [287/6158]
# ✅ 42 Chunks Indexed
# 📄 Processing: A Novel Method for Vectorization_chunks.json [288/6158]
# ✅ 20 Chunks Indexed
# 📄 Processing: A Novel Method for improving accuracy in neural ne_chunks.json [289/6158]
# ✅ 16 Chunks Indexed
# 📄 Processing: A Novel Micro-service Based Platform for Compositi_chunks.json [290/6158]
# ✅ 10 Chunks Indexed
# 📄 Processing: A Novel Modified Apriori Approach for Web Document_chunks.json [291/6158]
# ✅ 14 Chunks Indexed
# 📄 Processing: A Novel Review of Stability Techniques for Improve_chunks.json [292/6158]
# ✅ 24 Chunks Indexed
# 📄 Processing: A Novel Supervised Deep Learning Solution to Detec_chunks.json [293/6158]
# ✅ 27 Chunks Indexed
# 📄 Processing: A Novel Update Mechanism for Q-Networks Based On E_chunks.json [294/6158]
# ✅ 23 Chunks Indexed
# 📄 Processing: A Novel Weighted Distance Measure for Multi-Attrib_chunks.json [295/6158]
# ✅ 35 Chunks Indexed
# 📄 Processing: A Novel Zero-Trust Machine Learning Green Architec_chunks.json [296/6158]
# ✅ 18 Chunks Indexed
# 📄 Processing: A Physics-Based Context-Aware Approach for Anomaly_chunks.json [297/6158]
# ✅ 55 Chunks Indexed
# 📄 Processing: A Plug-and-play Scheme to Adapt Image Saliency Dee_chunks.json [298/6158]
# ✅ 48 Chunks Indexed
# 📄 Processing: A Practical Algorithm with Performance Guarantees _chunks.json [299/6158]
# ✅ 98 Chunks Indexed
# 📄 Processing: A Pre-trained Data Deduplication Model based on Ac_chunks.json [300/6158]
# ✅ 34 Chunks Indexed
# 📄 Processing: A Preliminary Investigation in the Molecular Basis_chunks.json [301/6158]
# ✅ 23 Chunks Indexed
# 📄 Processing: A Primer on Deep Learning for Causal Inference_chunks.json [302/6158]
# ✅ 86 Chunks Indexed
# 📄 Processing: A Primer on PAC-Bayesian Learning_chunks.json [303/6158]
# ✅ 50 Chunks Indexed
# 📄 Processing: A Privacy-Aware V-Model for Software Development_2019_chunks.json [304/6158]
# ✅ 18 Chunks Indexed
# 📄 Processing: A Privacy-Preserving Multi-Task Learning Framework_2020_chunks.json [305/6158]
# ✅ 33 Chunks Indexed
# 📄 Processing: A Private and Efficient Triple-Entry Accounting Pr_2023_chunks.json [306/6158]
# ✅ 23 Chunks Indexed
# 📄 Processing: A Probabilistic Theory of Deep Learning_chunks.json [307/6158]
# ✅ 95 Chunks Indexed
# 📄 Processing: A Proposal to Study Is High Quality Data All We Ne_chunks.json [308/6158]
# ✅ 20 Chunks Indexed
# 📄 Processing: A Prudent-Precedence Concurrency Control Protocol _chunks.json [309/6158]
# ✅ 24 Chunks Indexed
# 📄 Processing: A Public Image Database for Benchmark of Plant See_chunks.json [310/6158]
# ✅ 22 Chunks Indexed
# 📄 Processing: A Public Website for the Automated Assessment and _chunks.json [311/6158]
# ✅ 12 Chunks Indexed
# 📄 Processing: A Quantitative Perspective on Values of Domain Kno_chunks.json [312/6158]
# ✅ 29 Chunks Indexed
# 📄 Processing: A Quantitative and Qualitative Analysis of Suicide_chunks.json [313/6158]
# ✅ 17 Chunks Indexed
# 📄 Processing: A Question-Entailment Approach to Question Answeri_chunks.json [314/6158]
# ✅ 65 Chunks Indexed
# 📄 Processing: A Quick Introduction to Quantum Machine Learning f_chunks.json [315/6158]
# ✅ 84 Chunks Indexed
# 📄 Processing: A Real-Time Autonomous Highway Accident Detection _chunks.json [316/6158]
# ✅ 17 Chunks Indexed
# 📄 Processing: A Reliable Common-Sense Reasoning Socialbot Built _chunks.json [317/6158]
# ✅ 36 Chunks Indexed
# 📄 Processing: A Reply to Comment on 'Big Bang Nucleosynthesis an_chunks.json [318/6158]
# ✅ 14 Chunks Indexed
# 📄 Processing: A Resource Utilization Prediction Model for Cloud _2022_chunks.json [319/6158]
# ✅ 26 Chunks Indexed
# 📄 Processing: A Retrospective Systematic Study on Hierarchical S_chunks.json [320/6158]
# ✅ 59 Chunks Indexed
# 📄 Processing: A Retrospective of the Tutorial on Opportunities a_chunks.json [321/6158]
# ✅ 24 Chunks Indexed
# 📄 Processing: A Reverse Engineering Education Needs Analysis Sur_chunks.json [322/6158]
# ✅ 36 Chunks Indexed
# 📄 Processing: A Review and Comparison of AI Enhanced Side Channe_chunks.json [323/6158]
# ✅ 41 Chunks Indexed
# 📄 Processing: A Review of Automated Speech and Language Features_chunks.json [324/6158]
# ✅ 78 Chunks Indexed
# 📄 Processing: A Review of CUDA, MapReduce, and Pthreads Parallel_chunks.json [325/6158]
# ✅ 28 Chunks Indexed
# 📄 Processing: A Review of Deep Learning Techniques for Protein F_chunks.json [326/6158]
# ✅ 27 Chunks Indexed
# 📄 Processing: A Review of Deep Transfer Learning and Recent Adva_chunks.json [327/6158]
# ✅ 32 Chunks Indexed
# 📄 Processing: A Review of Formal Methods applied to Machine Lear_chunks.json [328/6158]
# ✅ 84 Chunks Indexed
# 📄 Processing: A Review of Intelligent Device Fault Diagnosis Tec_chunks.json [329/6158]
# ✅ 22 Chunks Indexed
# 📄 Processing: A Review of Machine Learning Classification Using _chunks.json [330/6158]
# ✅ 34 Chunks Indexed
# 📄 Processing: A Review of Privacy-preserving Federated Learning _chunks.json [331/6158]
# ✅ 60 Chunks Indexed
# 📄 Processing: A Review of Quantum Cybersecurity Threats Risks _2022_chunks.json [332/6158]
# ✅ 25 Chunks Indexed
# 📄 Processing: A Review of Star Schema Benchmark_chunks.json [333/6158]
# ✅ 12 Chunks Indexed
# 📄 Processing: A Review of Uncertainty Quantification in Deep Lea_chunks.json [334/6158]
# ✅ 281 Chunks Indexed
# 📄 Processing: A Review of Uncertainty for Deep Reinforcement Lea_chunks.json [335/6158]
# ✅ 32 Chunks Indexed
# 📄 Processing: A Review of Zero Trust Security Framework ZTF fo_2023_chunks.json [336/6158]
# ✅ 18 Chunks Indexed
# 📄 Processing: A Review of the Convergence of 5G6G Architecture a_chunks.json [337/6158]
# ✅ 79 Chunks Indexed
# 📄 Processing: A Review on Analysis and Visualization Methods for_chunks.json [338/6158]
# ✅ 40 Chunks Indexed
# 📄 Processing: A Review on Blockchain Technologies for an Advance_chunks.json [339/6158]
# ✅ 62 Chunks Indexed
# 📄 Processing: A Review on Machine Unlearning_chunks.json [340/6158]
# ✅ 35 Chunks Indexed
# 📄 Processing: A Review on Oracle Issues in Machine Learning_chunks.json [341/6158]
# ✅ 21 Chunks Indexed
# 📄 Processing: A Review on Quantum Search Algorithms_chunks.json [342/6158]
# ✅ 69 Chunks Indexed
# 📄 Processing: A Review on Security and Privacy of Internet of Me_chunks.json [343/6158]
# ✅ 36 Chunks Indexed
# 📄 Processing: A Review on The Division of Magnetic Resonant Pros_chunks.json [344/6158]
# ✅ 7 Chunks Indexed
# 📄 Processing: A Rich Recipe Representation as Plan to Support Ex_chunks.json [345/6158]
# ✅ 20 Chunks Indexed
# 📄 Processing: A Rigorous Link between Deep Ensembles and (Variat_chunks.json [346/6158]
# ✅ 78 Chunks Indexed
# 📄 Processing: A Roadmap Towards Automated and Regulated Robotic _chunks.json [347/6158]
# ✅ 61 Chunks Indexed
# 📄 Processing: A Roadmap to Domain Knowledge Integration in Machi_chunks.json [348/6158]
# ✅ 25 Chunks Indexed
# 📄 Processing: A Robust AUC Maximization Framework with Simultane_chunks.json [349/6158]
# ✅ 43 Chunks Indexed
# 📄 Processing: A Robust Interpretable Deep Learning Classifier fo_chunks.json [350/6158]
# ✅ 28 Chunks Indexed
# 📄 Processing: A Rule-Based Approach to Analyzing Database Schema_chunks.json [351/6158]
# ✅ 28 Chunks Indexed
# 📄 Processing: A Sampling Algebra for Aggregate Estimation_chunks.json [352/6158]
# ✅ 44 Chunks Indexed
# 📄 Processing: A Scalable Algorithm for Structure Identification _chunks.json [353/6158]
# ✅ 38 Chunks Indexed
# 📄 Processing: A Security Assessment tool for Quantum Threat Anal_chunks.json [354/6158]
# ✅ 62 Chunks Indexed
# 📄 Processing: A Security Credential Management System for V2X Co_chunks.json [355/6158]
# ✅ 76 Chunks Indexed
# 📄 Processing: A Selective Overview of Deep Learning_chunks.json [356/6158]
# ✅ 101 Chunks Indexed
# 📄 Processing: A Semantics-based Communication System for Dysphas_chunks.json [357/6158]
# ✅ 20 Chunks Indexed
# 📄 Processing: A Shared Task on Bandit Learning for Machine Trans_chunks.json [358/6158]
# ✅ 28 Chunks Indexed
# 📄 Processing: A Short Survey on Importance Weighting for Machine_chunks.json [359/6158]
# ✅ 70 Chunks Indexed
# 📄 Processing: A Simple Baseline for Travel Time Estimation using_chunks.json [360/6158]
# ✅ 47 Chunks Indexed
# 📄 Processing: A Simple Explanation of A Spectral Algorithm for L_chunks.json [361/6158]
# ✅ 8 Chunks Indexed
# 📄 Processing: A Simple Framework Uniting Visual In-context Learn_chunks.json [362/6158]
# ✅ 17 Chunks Indexed
# 📄 Processing: A Simple Framework to Quantify Different Types of _chunks.json [363/6158]
# ✅ 19 Chunks Indexed
# 📄 Processing: A Simple Illustration of Interleaved Learning usin_chunks.json [364/6158]
# ✅ 14 Chunks Indexed
# 📄 Processing: A Simple and Efficient Probabilistic Language mode_chunks.json [365/6158]
# ✅ 17 Chunks Indexed
# 📄 Processing: A Simple and General Debiased Machine Learning The_chunks.json [366/6158]
# ✅ 89 Chunks Indexed
# 📄 Processing: A Simplistic Machine Learning Approach to Contact _chunks.json [367/6158]
# ✅ 21 Chunks Indexed
# 📄 Processing: A Simplistic Model of Neural Scaling Laws Multiper_chunks.json [368/6158]
# ✅ 49 Chunks Indexed
# 📄 Processing: A Smart Manufacturing Service System Based on Edge_2019_chunks.json [369/6158]
# ✅ 29 Chunks Indexed
# 📄 Processing: A Socially Assistive Robot using Automated Plannin_chunks.json [370/6158]
# ✅ 17 Chunks Indexed
# 📄 Processing: A Solution to the Graceful Exit Problem in Pre-Big_chunks.json [371/6158]
# ✅ 34 Chunks Indexed
# 📄 Processing: A Space-Efficient Approach towards Distantly Homol_chunks.json [372/6158]
# ✅ 11 Chunks Indexed
# 📄 Processing: A Standalone Markerless 3D Tracker for Handheld Au_chunks.json [373/6158]
# ✅ 18 Chunks Indexed
# 📄 Processing: A Statistical Overview on Data Privacy_chunks.json [374/6158]
# ✅ 44 Chunks Indexed
# 📄 Processing: A Statistical Theory of Deep Learning via Proximal_chunks.json [375/6158]
# ✅ 46 Chunks Indexed
# 📄 Processing: A Story of Suo Motos, Judicial Activism, and Artic_chunks.json [376/6158]
# ✅ 26 Chunks Indexed
# 📄 Processing: A Streamlit-based Artificial Intelligence Trust Pl_chunks.json [377/6158]
# ✅ 9 Chunks Indexed
# 📄 Processing: A Structural Query System for Han Characters_chunks.json [378/6158]
# ✅ 69 Chunks Indexed
# 📄 Processing: A Structure-aware Approach for Efficient Graph Pro_chunks.json [379/6158]
# ✅ 31 Chunks Indexed
# 📄 Processing: A Study of Age and Sex Bias in Multiple Instance L_chunks.json [380/6158]
# ✅ 16 Chunks Indexed
# 📄 Processing: A Study of Moving from Cloud Computing to Fog Comp_2021_chunks.json [381/6158]
# ✅ 40 Chunks Indexed
# 📄 Processing: A Study on Altering PostgreSQL from Multi-Processe_chunks.json [382/6158]
# ✅ 39 Chunks Indexed
# 📄 Processing: A Study on Application of Spatial Data Mining Tech_chunks.json [383/6158]
# ✅ 13 Chunks Indexed
# 📄 Processing: A Study on Big Data Privacy Protection Models usin_2018_chunks.json [384/6158]
# ✅ 18 Chunks Indexed
# 📄 Processing: A Study on Consumer Perceptions Towards Telemedici_2024_chunks.json [385/6158]
# ✅ 11 Chunks Indexed
# 📄 Processing: A Study on Unsupervised Domain Adaptation for Sema_chunks.json [386/6158]
# ✅ 36 Chunks Indexed
# 📄 Processing: A Study on the Impact of Face Image Quality on Fac_chunks.json [387/6158]
# ✅ 35 Chunks Indexed
# 📄 Processing: A Study on the Vulnerability of Test Questions aga_chunks.json [388/6158]
# ✅ 18 Chunks Indexed
# 📄 Processing: A Survey Analyzing Generalization in Deep Reinforc_chunks.json [389/6158]
# ✅ 52 Chunks Indexed
# 📄 Processing: A Survey From Distributed Machine Learning to Dist_chunks.json [390/6158]
# ✅ 42 Chunks Indexed
# 📄 Processing: A Survey Time Travel in Deep Learning Space An Int_chunks.json [391/6158]
# ✅ 58 Chunks Indexed
# 📄 Processing: A Survey for Large Language Models in Biomedicine_chunks.json [392/6158]
# ✅ 51 Chunks Indexed
# 📄 Processing: A Survey for Solving Mixed Integer Programming via_2022_chunks.json [393/6158]
# ✅ 32 Chunks Indexed
# 📄 Processing: A Survey of Communication Protocols for Internet o_2018_chunks.json [394/6158]
# ✅ 68 Chunks Indexed
# 📄 Processing: A Survey of Community Search Over Big Graphs_chunks.json [395/6158]
# ✅ 181 Chunks Indexed
# 📄 Processing: A Survey of Computer Vision Technologies In Urban _chunks.json [396/6158]
# ✅ 114 Chunks Indexed
# 📄 Processing: A Survey of Current Datasets for Vision and Langua_chunks.json [397/6158]
# ✅ 22 Chunks Indexed
# 📄 Processing: A Survey of Deep Learning Based Software Refactori_chunks.json [398/6158]
# ✅ 116 Chunks Indexed
# 📄 Processing: A Survey of Deep Learning Techniques for Mobile Ro_chunks.json [399/6158]
# ✅ 44 Chunks Indexed
# 📄 Processing: A Survey of Few-Shot Learning for Biomedical Time _chunks.json [400/6158]
# ✅ 81 Chunks Indexed
# 📄 Processing: A Survey of Forex and Stock Price Prediction Using_chunks.json [401/6158]
# ✅ 78 Chunks Indexed
# 📄 Processing: A Survey of Game Theoretic Approaches for Adversar_chunks.json [402/6158]
# ✅ 41 Chunks Indexed
# 📄 Processing: A Survey of Human-in-the-loop for Machine Learning_2021_chunks.json [403/6158]
# ✅ 78 Chunks Indexed
# 📄 Processing: A Survey of Large-Scale Deep Learning Serving Syst_chunks.json [404/6158]
# ✅ 35 Chunks Indexed
# 📄 Processing: A Survey of Learning Causality with Data Problems _chunks.json [405/6158]
# ✅ 97 Chunks Indexed
# 📄 Processing: A Survey of Local Differential Privacy and Its Var_2023_chunks.json [406/6158]
# ✅ 22 Chunks Indexed
# 📄 Processing: A Survey of Machine Learning Methods and Challenge_chunks.json [407/6158]
# ✅ 165 Chunks Indexed
# 📄 Processing: A Survey of Machine Learning for Computer Architec_2021_chunks.json [408/6158]
# ✅ 105 Chunks Indexed
# 📄 Processing: A Survey of Machine Learning-Based Solutions for P_2021_chunks.json [409/6158]
# ✅ 58 Chunks Indexed
# 📄 Processing: A Survey of Network Requirements for Enabling Effe_chunks.json [410/6158]
# ✅ 30 Chunks Indexed
# 📄 Processing: A Survey of Online Auction Mechanism Design Using _chunks.json [411/6158]
# ✅ 31 Chunks Indexed
# 📄 Processing: A Survey of Optimization Methods from a Machine Le_chunks.json [412/6158]
# ✅ 125 Chunks Indexed
# 📄 Processing: A Survey of Research on Cloud Robotics and Automat_2015_chunks.json [413/6158]
# ✅ 54 Chunks Indexed
# 📄 Processing: A Survey of Singular Value Decomposition Methods f_chunks.json [414/6158]
# ✅ 28 Chunks Indexed
# 📄 Processing: A Survey of Techniques All Classifiers Can Learn f_chunks.json [415/6158]
# ✅ 84 Chunks Indexed
# 📄 Processing: A Survey of Topological Machine Learning Methods_2021_chunks.json [416/6158]
# ✅ 47 Chunks Indexed
# 📄 Processing: A Survey of Traversability Estimation for Mobile R_chunks.json [417/6158]
# ✅ 55 Chunks Indexed
# 📄 Processing: A Survey of Vision Transformers in Autonomous Driv_chunks.json [418/6158]
# ✅ 25 Chunks Indexed
# 📄 Processing: A Survey on AI-Driven Digital Twins in Industry 4._2021_chunks.json [419/6158]
# ✅ 96 Chunks Indexed
# 📄 Processing: A Survey on Bias and Fairness in Machine Learning_2019_chunks.json [420/6158]
# ✅ 82 Chunks Indexed
# 📄 Processing: A Survey on Blockchain Technology Evolution Arch_2021_chunks.json [421/6158]
# ✅ 96 Chunks Indexed
# 📄 Processing: A Survey on Blood Pressure Measurement Technologie_chunks.json [422/6158]
# ✅ 90 Chunks Indexed
# 📄 Processing: A Survey on Conversational Recommender Systems_chunks.json [423/6158]
# ✅ 86 Chunks Indexed
# 📄 Processing: A Survey on Cross-Architectural IoT Malware Threat_chunks.json [424/6158]
# ✅ 72 Chunks Indexed
# 📄 Processing: A Survey on Data Collection for Machine Learning _2018_chunks.json [425/6158]
# ✅ 82 Chunks Indexed
# 📄 Processing: A Survey on Data-Centric AI Tabular Learning from _chunks.json [426/6158]
# ✅ 29 Chunks Indexed
# 📄 Processing: A Survey on Deep Clustering From the Prior Perspec_chunks.json [427/6158]
# ✅ 54 Chunks Indexed
# 📄 Processing: A Survey on Deep Graph Generation Methods and Appl_chunks.json [428/6158]
# ✅ 91 Chunks Indexed
# 📄 Processing: A Survey on Deep Learning Methods for Robot Vision_chunks.json [429/6158]
# ✅ 109 Chunks Indexed
# 📄 Processing: A Survey on Deep Learning Techniques for Video Ano_chunks.json [430/6158]
# ✅ 40 Chunks Indexed
# 📄 Processing: A Survey on Deep Learning Toolkits and Libraries f_chunks.json [431/6158]
# ✅ 31 Chunks Indexed
# 📄 Processing: A Survey on Deep Learning for Localization and Map_chunks.json [432/6158]
# ✅ 110 Chunks Indexed
# 📄 Processing: A Survey on Deep Learning for Skeleton-Based Human_chunks.json [433/6158]
# ✅ 146 Chunks Indexed
# 📄 Processing: A Survey on Deep Learning with Noisy Labels How to_chunks.json [434/6158]
# ✅ 30 Chunks Indexed
# 📄 Processing: A Survey on Detection of LLMs-Generated Content_chunks.json [435/6158]
# ✅ 61 Chunks Indexed
# 📄 Processing: A Survey on Device Behavior Fingerprinting Data So_chunks.json [436/6158]
# ✅ 130 Chunks Indexed
# 📄 Processing: A Survey on Differential Privacy with Machine Lear_chunks.json [437/6158]
# ✅ 31 Chunks Indexed
# 📄 Processing: A Survey on Distributed Denial of Service DDoS A_2019_chunks.json [438/6158]
# ✅ 55 Chunks Indexed
# 📄 Processing: A Survey on Distributed Machine Learning_2019_chunks.json [439/6158]
# ✅ 86 Chunks Indexed
# 📄 Processing: A Survey on Distributed Machine Learning_chunks.json [440/6158]
# ✅ 83 Chunks Indexed
# 📄 Processing: A Survey on Ensemble Learning under the Era of Dee_chunks.json [441/6158]
# ✅ 111 Chunks Indexed
# 📄 Processing: A Survey on Evolutionary Computation for Computer _chunks.json [442/6158]
# ✅ 95 Chunks Indexed
# 📄 Processing: A Survey on Eye-Gaze Tracking Techniques_chunks.json [443/6158]
# ✅ 23 Chunks Indexed
# 📄 Processing: A Survey on Hypergraph Neural Networks An In-Depth_chunks.json [444/6158]
# ✅ 72 Chunks Indexed
# 📄 Processing: A Survey on Infrared Image and Video Sets_chunks.json [445/6158]
# ✅ 75 Chunks Indexed
# 📄 Processing: A Survey on Internet of Things and Cloud Computing_2019_chunks.json [446/6158]
# ✅ 105 Chunks Indexed
# 📄 Processing: A Survey on Large Language Model (LLM) Security an_chunks.json [447/6158]
# ✅ 120 Chunks Indexed
# 📄 Processing: A Survey on Machine Learning Techniques for Routin_2021_chunks.json [448/6158]
# ✅ 109 Chunks Indexed
# 📄 Processing: A Survey on Multi-Turn Interaction Capabilities of_chunks.json [449/6158]
# ✅ 71 Chunks Indexed
# 📄 Processing: A Survey on Neural Architecture Search_chunks.json [450/6158]
# ✅ 100 Chunks Indexed
# 📄 Processing: A Survey on Nonconvex Regularization Based Sparse _chunks.json [451/6158]
# ✅ 100 Chunks Indexed
# 📄 Processing: A Survey on Offensive AI Within Cybersecurity_chunks.json [452/6158]
# ✅ 64 Chunks Indexed
# 📄 Processing: A Survey on Property-Preserving Database Encryptio_chunks.json [453/6158]
# ✅ 110 Chunks Indexed
# 📄 Processing: A Survey on Protein Representation Learning Retros_chunks.json [454/6158]
# ✅ 42 Chunks Indexed
# 📄 Processing: A Survey on Recent Advances in Named Entity Recogn_chunks.json [455/6158]
# ✅ 37 Chunks Indexed
# 📄 Processing: A Survey on Resilient Machine Learning_chunks.json [456/6158]
# ✅ 35 Chunks Indexed
# 📄 Processing: A Survey on Spatial Co-location Patterns Discovery_chunks.json [457/6158]
# ✅ 18 Chunks Indexed
# 📄 Processing: A Survey on State-of-the-art Deep Learning Applica_chunks.json [458/6158]
# ✅ 141 Chunks Indexed
# 📄 Processing: A Survey on Structure-Preserving Graph Transformer_chunks.json [459/6158]
# ✅ 27 Chunks Indexed
# 📄 Processing: A Survey on Uncertainty Quantification of Large La_chunks.json [460/6158]
# ✅ 96 Chunks Indexed
# 📄 Processing: A Survey on the Explainability of Supervised Machi_2020_chunks.json [461/6158]
# ✅ 139 Chunks Indexed
# 📄 Processing: A Sweet Rabbit Hole by DARCY Using Honeypots to De_chunks.json [462/6158]
# ✅ 38 Chunks Indexed
# 📄 Processing: A System for Automatic Rice Disease Detection from_chunks.json [463/6158]
# ✅ 20 Chunks Indexed
# 📄 Processing: A Systematic Bias of Machine Learning Regression M_chunks.json [464/6158]
# ✅ 45 Chunks Indexed
# 📄 Processing: A Systematic Literature Review on Cloud Computing _2021_chunks.json [465/6158]
# ✅ 49 Chunks Indexed
# 📄 Processing: A Systematic Survey of Text Worlds as Embodied Nat_chunks.json [466/6158]
# ✅ 54 Chunks Indexed
# 📄 Processing: A Tableau Calculus for Pronoun Resolution_chunks.json [467/6158]
# ✅ 41 Chunks Indexed
# 📄 Processing: A Taxonomy of Cyber Defence Strategies Against Fal_chunks.json [468/6158]
# ✅ 84 Chunks Indexed
# 📄 Processing: A Taxonomy of Explainable Bayesian Networks_chunks.json [469/6158]
# ...
# ✅ 117 Chunks Indexed
# 📄 Processing: The Neglected Tails in Vision-Language Models_chunks.json [6011/6158]
# ✅ 58 Chunks Indexed
# 📄 Processing: The New Frontier of Cybersecurity Emerging Threat_2023_chunks.json [6012/6158]
# ✅ 24 Chunks Indexed
# 📄 Processing: The Next Big Thing(s) in Unsupervised Machine Lear_chunks.json [6013/6158]
# ✅ 50 Chunks Indexed
# 📄 Processing: The Nonequilibrium Many-Body Problem as a paradigm_chunks.json [6014/6158]
# ✅ 66 Chunks Indexed
# 📄 Processing: The Open Autonomy Safety Case Framework_chunks.json [6015/6158]
# ✅ 24 Chunks Indexed
# 📄 Processing: The Optical Gravitational Lensing Experiment. Inte_chunks.json [6016/6158]
# ✅ 26 Chunks Indexed
# 📄 Processing: The Optimization of Running Queries in Relational _chunks.json [6017/6158]
# ✅ 14 Chunks Indexed
# 📄 Processing: The PHOTON Wizard -- Towards Educational Machine L_chunks.json [6018/6158]
# ✅ 12 Chunks Indexed
# 📄 Processing: The Past, Current, and Future of Neonatal Intensiv_chunks.json [6019/6158]
# ✅ 97 Chunks Indexed
# 📄 Processing: The Point of View of a Sentiment Towards Clinician_chunks.json [6020/6158]
# ✅ 34 Chunks Indexed
# 📄 Processing: The Power of Words Generating PowerShell Attacks f_chunks.json [6021/6158]
# ✅ 51 Chunks Indexed
# 📄 Processing: The Preference Learning Toolbox_chunks.json [6022/6158]
# ✅ 9 Chunks Indexed
# 📄 Processing: The Promise and Peril of Artificial Intelligence -_chunks.json [6023/6158]
# ✅ 33 Chunks Indexed
# 📄 Processing: The Pros and Cons of Using Machine Learning and In_chunks.json [6024/6158]
# ✅ 16 Chunks Indexed
# 📄 Processing: The Rise and Fall of Cryptocurrencies Defining the_chunks.json [6025/6158]
# ✅ 86 Chunks Indexed
# 📄 Processing: The Role of AI in Cybersecurity Addressing Threat_2024_chunks.json [6026/6158]
# ✅ 21 Chunks Indexed
# 📄 Processing: The Role of AI in Drug Discovery Challenges, Oppor_chunks.json [6027/6158]
# ✅ 22 Chunks Indexed
# 📄 Processing: The Role of Blockchain Technology in Augmenting Su_2021_chunks.json [6028/6158]
# ✅ 56 Chunks Indexed
# 📄 Processing: The Role of Humans in Surgery Automation_2022_chunks.json [6029/6158]
# ✅ 57 Chunks Indexed
# 📄 Processing: The Roles of Supervised Machine Learning in System_chunks.json [6030/6158]
# ✅ 133 Chunks Indexed
# 📄 Processing: The Russian Drug Reaction Corpus and Neural Models_chunks.json [6031/6158]
# ✅ 30 Chunks Indexed
# 📄 Processing: The SIMBAD astronomical database_chunks.json [6032/6158]
# ✅ 42 Chunks Indexed
# 📄 Processing: The SP Theory of Intelligence as a Foundation for _chunks.json [6033/6158]
# ✅ 26 Chunks Indexed
# 📄 Processing: The SP theory of intelligence and the representati_chunks.json [6034/6158]
# ✅ 79 Chunks Indexed
# 📄 Processing: The SP theory of intelligence benefits and applica_chunks.json [6035/6158]
# ✅ 45 Chunks Indexed
# 📄 Processing: The Sandwich meta-framework for architecture agnos_chunks.json [6036/6158]
# ✅ 44 Chunks Indexed
# 📄 Processing: The Scientific Method in the Science of Machine Le_chunks.json [6037/6158]
# ✅ 25 Chunks Indexed
# 📄 Processing: The Snowflake Elastic Data Warehouse_2016_chunks.json [6038/6158]
# ✅ 48 Chunks Indexed
# 📄 Processing: The Spatial Nearest Neighbor Skyline Queries_chunks.json [6039/6158]
# ✅ 23 Chunks Indexed
# 📄 Processing: The State of Applying Artificial Intelligence to T_chunks.json [6040/6158]
# ✅ 39 Chunks Indexed
# 📄 Processing: The State of Julia for Scientific Machine Learning_chunks.json [6041/6158]
# ✅ 30 Chunks Indexed
# 📄 Processing: The Structural Biology and Critical Evaluation of _chunks.json [6042/6158]
# ✅ 62 Chunks Indexed
# 📄 Processing: The TESLA Requirements Database_chunks.json [6043/6158]
# ✅ 8 Chunks Indexed
# 📄 Processing: The Tandem Duplication Distance is NP-hard_chunks.json [6044/6158]
# ✅ 55 Chunks Indexed
# 📄 Processing: The Task-oriented Queries Benchmark (ToQB)_chunks.json [6045/6158]
# ✅ 44 Chunks Indexed
# 📄 Processing: The Threat of Adversarial Attacks on Machine Learn_chunks.json [6046/6158]
# ✅ 103 Chunks Indexed
# 📄 Processing: The TikToking troll and weaponization of conscienc_chunks.json [6047/6158]
# ✅ 10 Chunks Indexed
# 📄 Processing: The Top 10 Topics in Machine Learning Revisited A _chunks.json [6048/6158]
# ✅ 10 Chunks Indexed
# 📄 Processing: The Transformative Potential of Artificial Intelli_2023_chunks.json [6049/6158]
# ✅ 32 Chunks Indexed
# 📄 Processing: The Tribes of Machine Learning and the Realm of Co_chunks.json [6050/6158]
# ✅ 69 Chunks Indexed
# 📄 Processing: The Trickle-down Impact of Reward (In-)consistency_chunks.json [6051/6158]
# ✅ 88 Chunks Indexed
# 📄 Processing: The UCSD HIRESKeckI Damped Lya Abundance Database _chunks.json [6052/6158]
# ✅ 77 Chunks Indexed
# 📄 Processing: The Unreasonable Effectiveness of Deep Learning in_chunks.json [6053/6158]
# ✅ 24 Chunks Indexed
# 📄 Processing: The Use of Privacy Enhancing Technologies for Biom_2009_chunks.json [6054/6158]
# ✅ 27 Chunks Indexed
# 📄 Processing: The Value of Collaboration in Convex Machine Learn_chunks.json [6055/6158]
# ✅ 54 Chunks Indexed
# 📄 Processing: The Vertica Analytic Database C-Store 7 Years Late_chunks.json [6056/6158]
# ✅ 46 Chunks Indexed
# 📄 Processing: The Vision of Self-Evolving Computing Systems_chunks.json [6057/6158]
# ✅ 45 Chunks Indexed
# 📄 Processing: The VizieR database of Astronomical Catalogues_chunks.json [6058/6158]
# ✅ 31 Chunks Indexed
# 📄 Processing: The XSTAR Atomic Database_chunks.json [6059/6158]
# ✅ 113 Chunks Indexed
# 📄 Processing: The Zones Algorithm for Finding Points-Near-a-Poin_chunks.json [6060/6158]
# ✅ 56 Chunks Indexed
# 📄 Processing: The asymptotic distribution of the $k$-Robinson-Fo_chunks.json [6061/6158]
# ✅ 49 Chunks Indexed
# 📄 Processing: The beamed jet and quasar core of the distant blaz_chunks.json [6062/6158]
# ✅ 49 Chunks Indexed
# 📄 Processing: The big bang of an epidemic_chunks.json [6063/6158]
# ✅ 53 Chunks Indexed
# 📄 Processing: The birth of Romanian BERT_chunks.json [6064/6158]
# ✅ 13 Chunks Indexed
# 📄 Processing: The business model bank conceptualizing a database_chunks.json [6065/6158]
# ✅ 6 Chunks Indexed
# 📄 Processing: The challenge of simultaneous object detection and_chunks.json [6066/6158]
# ✅ 53 Chunks Indexed
# 📄 Processing: The complementarity of a diverse range of deep lea_chunks.json [6067/6158]
# ✅ 61 Chunks Indexed
# 📄 Processing: The digital harms of smart home devices A systemat_chunks.json [6068/6158]
# ✅ 55 Chunks Indexed
# 📄 Processing: The ethics of advancing artificial intelligence in_2023_chunks.json [6069/6158]
# ✅ 29 Chunks Indexed
# 📄 Processing: The ethics of using artificial intelligence in sci_2024_chunks.json [6070/6158]
# ✅ 86 Chunks Indexed
# 📄 Processing: The evaluation of geometric queries constraint dat_chunks.json [6071/6158]
# ✅ 83 Chunks Indexed
# 📄 Processing: The evolutionary dynamics of protein-protein inter_chunks.json [6072/6158]
# ✅ 88 Chunks Indexed
# 📄 Processing: The future is in your hands - Handheld ultrasound _2020_chunks.json [6073/6158]
# ✅ 8 Chunks Indexed
# 📄 Processing: The future of Cybersecurity in renewable energy sy_2024_chunks.json [6074/6158]
# ✅ 77 Chunks Indexed
# 📄 Processing: The gene function prediction challenge large langu_chunks.json [6075/6158]
# ✅ 30 Chunks Indexed
# 📄 Processing: The ground-based solar observations database BASS _chunks.json [6076/6158]
# ✅ 4 Chunks Indexed
# 📄 Processing: The impact of big winners on passive and active eq_chunks.json [6077/6158]
# ✅ 26 Chunks Indexed
# 📄 Processing: The impact of prior knowledge on causal structure _chunks.json [6078/6158]
# ✅ 96 Chunks Indexed
# 📄 Processing: The impact of technology on Urban infrastructure_2023_chunks.json [6079/6158]
# ✅ 12 Chunks Indexed
# 📄 Processing: The importance of cybersecurity in protecting rene_2024_chunks.json [6080/6158]
# ✅ 87 Chunks Indexed
# 📄 Processing: The integration of artificial intelligence in cybe_2024_chunks.json [6081/6158]
# ✅ 51 Chunks Indexed
# 📄 Processing: The lifecycle of provenance metadata and its assoc_chunks.json [6082/6158]
# ✅ 20 Chunks Indexed
# 📄 Processing: The many faces of deep learning_chunks.json [6083/6158]
# ✅ 34 Chunks Indexed
# 📄 Processing: The multi-tenancy queueing system QuAntri for pu_2022_chunks.json [6084/6158]
# ✅ 25 Chunks Indexed
# 📄 Processing: The perceptions of the meaning and value of analyt_2017_chunks.json [6085/6158]
# ✅ 28 Chunks Indexed
# 📄 Processing: The pitfalls of using open data to develop deep le_chunks.json [6086/6158]
# ✅ 11 Chunks Indexed
# 📄 Processing: The role of hydrophobic interactions in folding of_chunks.json [6087/6158]
# ✅ 115 Chunks Indexed
# 📄 Processing: The similarity metric_chunks.json [6088/6158]
# ✅ 57 Chunks Indexed
# 📄 Processing: The state of quantum computing applications in hea_2023_chunks.json [6089/6158]
# ✅ 39 Chunks Indexed
# 📄 Processing: The university-industry knowledge relationship Ana_chunks.json [6090/6158]
# ✅ 28 Chunks Indexed
# 📄 Processing: The use of NHS patient data report by the Nationa_2017_chunks.json [6091/6158]
# ✅ 9 Chunks Indexed
# 📄 Processing: The use of artificial intelligence in scientific r_2024_chunks.json [6092/6158]
# ✅ 17 Chunks Indexed
# 📄 Processing: The use of deep learning in interventional radioth_chunks.json [6093/6158]
# ✅ 78 Chunks Indexed
# 📄 Processing: The whack-a-mole governance challenge for AI-enabl_chunks.json [6094/6158]
# ✅ 64 Chunks Indexed
# 📄 Processing: Theoretical Impediments to Machine Learning With S_chunks.json [6095/6158]
# ✅ 18 Chunks Indexed
# 📄 Processing: Theoretical Models of Learning to Learn_chunks.json [6096/6158]
# ✅ 39 Chunks Indexed
# 📄 Processing: Theoretical Robopsychology Samu Has Learned Turing_chunks.json [6097/6158]
# ✅ 19 Chunks Indexed
# 📄 Processing: Theory of Graph Neural Networks Representation and_chunks.json [6098/6158]
# ✅ 62 Chunks Indexed
# 📄 Processing: TherML Thermodynamics of Machine Learning_chunks.json [6099/6158]
# ✅ 43 Chunks Indexed
# 📄 Processing: TheraGen Therapy for Every Generation_chunks.json [6100/6158]
# ✅ 32 Chunks Indexed
# 📄 Processing: Think Before You Speak Cultivating Communication S_chunks.json [6101/6158]
# ✅ 59 Chunks Indexed
# 📄 Processing: Thinking beyond chatbots' threat to education Visu_chunks.json [6102/6158]
# ✅ 28 Chunks Indexed
# 📄 Processing: Thistle A Vector Database in Rust_chunks.json [6103/6158]
# ✅ 9 Chunks Indexed
# 📄 Processing: Threat Classification on Deployed Optical Networks_chunks.json [6104/6158]
# ✅ 11 Chunks Indexed
# 📄 Processing: Threat Modeling of Cyber-Physical Systems in Pract_chunks.json [6105/6158]
# ✅ 26 Chunks Indexed
# 📄 Processing: Threat Modelling and Risk Analysis for Large Langu_chunks.json [6106/6158]
# ✅ 26 Chunks Indexed
# 📄 Processing: Three Applications of Conformal Prediction for Rat_chunks.json [6107/6158]
# ✅ 23 Chunks Indexed
# 📄 Processing: Three Approaches for Personalization with Applicat_chunks.json [6108/6158]
# ✅ 53 Chunks Indexed
# 📄 Processing: Three algorithms for solving high-dimensional full_chunks.json [6109/6158]
# ✅ 54 Chunks Indexed
# 📄 Processing: Three-Dimensional Postoperative Results Prediction_2022_chunks.json [6110/6158]
# ✅ 33 Chunks Indexed
# 📄 Processing: Three-fluid plasmas in star formation I. Magneto-h_2008_chunks.json [6111/6158]
# ✅ 62 Chunks Indexed
# 📄 Processing: TigerGraph A Native MPP Graph Database_chunks.json [6112/6158]
# ✅ 80 Chunks Indexed
# 📄 Processing: Tight Bounds for Online Edge Coloring_chunks.json [6113/6158]
# ✅ 95 Chunks Indexed
# 📄 Processing: TikTalk A Video-Based Dialogue Dataset for Multi-M_chunks.json [6114/6158]
# ✅ 43 Chunks Indexed
# 📄 Processing: Time Series Forecasting With Deep Learning A Surve_chunks.json [6115/6158]
# ✅ 33 Chunks Indexed
# 📄 Processing: Time Series Predictions in Unmonitored Sites A Sur_chunks.json [6116/6158]
# ✅ 115 Chunks Indexed
# 📄 Processing: Time series modeling by a regression approach base_chunks.json [6117/6158]
# ✅ 37 Chunks Indexed
# 📄 Processing: Time-lagged autoencoders Deep learning of slow col_chunks.json [6118/6158]
# ✅ 27 Chunks Indexed
# 📄 Processing: Timely Feedback in Unstructured Cybersecurity Exer_chunks.json [6119/6158]
# ✅ 18 Chunks Indexed
# 📄 Processing: Tiny Deep Ensemble Uncertainty Estimation in Edge _chunks.json [6120/6158]
# ✅ 33 Chunks Indexed
# 📄 Processing: TinyChart Efficient Chart Understanding with Visua_chunks.json [6121/6158]
# ✅ 48 Chunks Indexed
# 📄 Processing: To BLOB or Not To BLOB Large Object Storage in a D_chunks.json [6122/6158]
# ✅ 27 Chunks Indexed
# 📄 Processing: To ChatGPT, or not to ChatGPT That is the question_chunks.json [6123/6158]
# ✅ 22 Chunks Indexed
# 📄 Processing: To Recommend or Not Recommendability Identificatio_chunks.json [6124/6158]
# ✅ 25 Chunks Indexed
# 📄 Processing: To Trust or Distrust Trust Measures Validating Que_chunks.json [6125/6158]
# ✅ 59 Chunks Indexed
# 📄 Processing: To Trust or Not to Trust Towards a novel approach _chunks.json [6126/6158]
# ✅ 29 Chunks Indexed
# 📄 Processing: Token Trails Navigating Contextual Depths in Conve_chunks.json [6127/6158]
# ✅ 22 Chunks Indexed
# 📄 Processing: Token Transformation Matters Towards Faithful Post_chunks.json [6128/6158]
# ✅ 30 Chunks Indexed
# 📄 Processing: Top Ten Challenges Towards Agentic Neural Graph Da_chunks.json [6129/6158]
# ✅ 40 Chunks Indexed
# 📄 Processing: Top-Down Multilevel Simulation of Tumor Response t_chunks.json [6130/6158]
# ✅ 46 Chunks Indexed
# 📄 Processing: Top-k Query Processing on Encrypted Databases with_chunks.json [6131/6158]
# ✅ 87 Chunks Indexed
# 📄 Processing: Topic Modeling in Marathi_chunks.json [6132/6158]
# ✅ 9 Chunks Indexed
# 📄 Processing: Topological AI forecasting of future dominating vi_chunks.json [6133/6158]
# ✅ 7 Chunks Indexed
# 📄 Processing: Topological Data Analysis for Anomaly Detection in_chunks.json [6134/6158]
# ✅ 20 Chunks Indexed
# 📄 Processing: Topological Deep Learning A Review of an Emerging _chunks.json [6135/6158]
# ✅ 34 Chunks Indexed
# 📄 Processing: Topological Interpretability for Deep-Learning_chunks.json [6136/6158]
# ✅ 39 Chunks Indexed
# 📄 Processing: Torch.fx Practical Program Capture and Transformat_chunks.json [6137/6158]
# ✅ 43 Chunks Indexed
# 📄 Processing: Tourism Demand Forecasting An Ensemble Deep Learni_chunks.json [6138/6158]
# ✅ 54 Chunks Indexed
# 📄 Processing: Toward Interactive Bug Reporting for (Android App)_chunks.json [6139/6158]
# ✅ 56 Chunks Indexed
# 📄 Processing: Toward Parts-Based Scene Understanding with Pixel-_chunks.json [6140/6158]
# ✅ 33 Chunks Indexed
# 📄 Processing: Toward Robust Canine Cardiac Diagnosis Deep Protot_chunks.json [6141/6158]
# ✅ 12 Chunks Indexed
# 📄 Processing: Toward Systematic Design Considerations of Organiz_chunks.json [6142/6158]
# ✅ 23 Chunks Indexed
# 📄 Processing: Toward a Dialogue System Using a Large Language Mo_chunks.json [6143/6158]
# ✅ 15 Chunks Indexed
# 📄 Processing: Toward a view-based data cleaning architecture_chunks.json [6144/6158]
# ✅ 15 Chunks Indexed
# 📄 Processing: Toward perfect reads self-correction of short read_chunks.json [6145/6158]
# ✅ 41 Chunks Indexed
# 📄 Processing: Toward the automated analysis of complex diseases _chunks.json [6146/6158]
# ✅ 27 Chunks Indexed
# 📄 Processing: Towards A Rigorous Science of Interpretable Machin_chunks.json [6147/6158]
# ✅ 23 Chunks Indexed
# 📄 Processing: Towards AI Lesion Tracking in PETCT Imaging A Siam_chunks.json [6148/6158]
# ✅ 35 Chunks Indexed
# 📄 Processing: Towards Adaptive RF Fingerprint-based Authenticati_chunks.json [6149/6158]
# ✅ 13 Chunks Indexed
# 📄 Processing: Towards Adversarial Malware Detection Lessons Lear_chunks.json [6150/6158]
# ✅ 85 Chunks Indexed
# 📄 Processing: Towards Automated Knowledge Integration From Human_chunks.json [6151/6158]
# ✅ 100 Chunks Indexed
# 📄 Processing: Towards Automated Website Classification by Deep L_chunks.json [6152/6158]
# ✅ 56 Chunks Indexed
# 📄 Processing: Towards Better Understanding of Cybercrime The Rol_chunks.json [6153/6158]
# ✅ 30 Chunks Indexed
# 📄 Processing: Towards Black-box Attacks on Deep Learning Apps_chunks.json [6154/6158]
# ✅ 42 Chunks Indexed
# 📄 Processing: Towards CRISP-ML(Q) A Machine Learning Process Mod_chunks.json [6155/6158]
# ✅ 50 Chunks Indexed
# 📄 Processing: Towards Characterizing Cyber Networks with Large L_chunks.json [6156/6158]
# ✅ 17 Chunks Indexed
# 📄 Processing: Towards Classification of Web ontologies using the_chunks.json [6157/6158]
# ✅ 9 Chunks Indexed
# 📄 Processing: Towards Clinical Prediction with Transparency An E_chunks.json [6158/6158]
# ✅ 47 Chunks Indexed
# 🚀 All Chunks Processed!

# %% [markdown]
# 🧠 How ChromaDB Retrieves Relevant Chunks (Cosine Similarity)
#
# * When a user asks a query like:
#
# - 👉 "Summarize the methodology of this article"
# - 👉 "What is the model architecture used in this paper?"
# - 👉 "Summarize the conclusion in 200 words"
#
# * What Happens Behind the Scenes?
# - User Query 🔍: The user enters a query like:
#
# query = "Summarize the methodology used in this article"
#
# - ChromaDB Fetches Relevant Chunks : The Vector Database finds chunks that are most similar to the query embedding.
# Generate Query Embedding 🧠: The query is converted into an embedding vector using the same model (all-MiniLM-L6-v2):
#
# ###### query_embedding = embedding_model.encode(query).tolist()
#
# - Cosine Similarity Search 🔥: ChromaDB automatically compares the query embedding against ALL stored embeddings in the Vector Database using cosine similarity.

# %% [markdown]
# # ChromaDB Retrieval Code

# %%
query = """cademic community. As an illustration of the scale of the field’s growth, the number of submis-
sions to NeurIPS, a primary conference on ML methods, has quadrupled in six years, going from
1,678submissionsin2014to6,743in2019[ 38].Nevertheless,therearestillplentyofpracticalcon-
siderationsthataffectthemodellearningstage.Inthissection,wediscussissuesconcerningthree
steps within model learning: model selection, training, and hyper-parameter selection.
4.1 Model Selection
In many practical cases the selection of a model is decided by one key characteristic of a model:
complexity.Despiteareassuchasdeeplearningandreinforcementlearninggaininginpopularity
with the research community, in practice simpler models are often chosen. Such models include
shallowneuralnetworkarchitectures,simpleapproachesbasedon PrincipalComponentAnal-
ysis (PCA), decision trees, and random forests.
Simple models can be used as a way to prove the concept of the proposed ML solution and get
the end-to-end setup in place. This approach reduces the time to get a deployed solution, allows
the collection of important feedback, and also helps avoid overcomplicated designs. This was the
case reported by Haldar et al. [39]. In the process of applying machine learning to AirBnB search,
the team started with a complex deep learning model. The team was quickly overwhelmed by its
complexityandendedupconsumingdevelopmentcycles.Afterseveralfaileddeploymentattempts
the neural network architecture was drastically simplified: a single hidden layer NN with 32 fully
connected ReLU activations. Even such a simple model had value, as it allowed the building of a
whole pipeline of deploying ML models"""
query_embedding = embedding_model.encode(query).tolist()

# %%
# 🔥 Retrieve Top 5 Most Similar Chunks
results = collection.query(
    query_embeddings=[query_embedding],
    n_results=5,
    include=["documents", "distances"]
)

# %%
for i in range(len(results["documents"][0])):
    print(f"Chunk: {results['documents'][0][i]}")
    print(f"Similarity Score: {1 - results['distances'][0][i]}")
    print("=" * 80)
# Out:
# Chunk: academic community. As an illustration of the scale of the field’s growth, the number of submis-
# sions to NeurIPS, a primary conference on ML methods, has quadrupled in six years, going from
# 1,678submissionsin2014to6,743in2019[ 38].Nevertheless,therearestillplentyofpracticalcon-
# siderationsthataffectthemodellearningstage.Inthissection,wediscussissuesconcerningthree
# steps within model learning: model selection, training, and hyper-parameter selection.
# 4.1 Model Selection
# In many practical cases the selection of a model is decided by one key characteristic of a model:
# complexity.Despiteareassuchasdeeplearningandreinforcementlearninggaininginpopularity
# with the research community, in practice simpler models are often chosen. Such models include
# shallowneuralnetworkarchitectures,simpleapproachesbasedon PrincipalComponentAnal-
# ysis (PCA), decision trees, and random forests.
# Simple models can be used as a way to prove the concept of the proposed ML solution and get
# the end-to-end setup in place. This approach reduces the time to get a deployed solution, allows
# the collection of important feedback, and also helps avoid overcomplicated designs. This was the
# case reported by Haldar et al. [39]. In the process of applying machine learning to AirBnB search,
# the team started with a complex deep learning model. The team was quickly overwhelmed by its
# complexityandendedupconsumingdevelopmentcycles.Afterseveralfaileddeploymentattempts
# the neural network architecture was drastically simplified: a single hidden layer NN with 32 fully
# connected ReLU activations. Even such a simple model had value, as it allowed the building of a
# whole pipeline of deploying ML models in a production setting, while providing reasonably good
# performance.4 Over time the model evolved, with a second hidden layer being added, but it still
# remained fairly simple, never reaching the initially intended level of complexity.
# 3For further discussion of the role user interface can play in adoption of an ML system, see Section7.3.
# 4We discuss more benefits of setting up the automated deployment pipeline in Section6.3.
# ACM Computing Surveys, Vol. 55, No. 6, Article 114. Publication date: December 2022.114:8 A. Paleyes et al.
# Another advantage that less complex models can offer is their relatively modest hardware re-
# quirements. This becomes a key decision point in resource-constrained environments, as shown
# by Wagstaff et al. [40]. They worked on deploying ML models to a range of scientific instruments
# onboard the Europa Clipper spacecraft. Spacecraft design is always a tradeoff between the to-
# tal weight, robustness, and the number of scientific tools onboard. Therefore, computational re-
# sourcesarescarceandtheirusagehastobeassmallaspossible.Theserequirementsnaturallyfavor
# the models that are light on computational demands. The team behind Europa Clipper used ma-
# chine learning for three anomaly detection tasks; some models took time series data as input and
# some models took images, and on all three occasions simple threshold or PCA-based techniques
# were implemented. They were specifically chosen because of their robust performance and low
# demand for computational power.
# A further example of a resource-constrained environment is wireless cellular networks, where
# energy,memoryconsumption,anddatatransmissionareverylimited.Mostadvancedtechniques,
# suchasdeeplearning,arenotconsideredyetforpracticaldeployment,despitebeingabletohandle
# high-dimensional mobile network data [41].
# Similarity Score: 0.9680073261260986
# ================================================================================
# Chunk: complexity and performance on the training dataset), and Resampling
# techniques (using approaches such as cross -validation). Hyperparameter
# selection is another category of model selection. This category comprises
# certain techniques that are used to search for the best hyperparameters
# settings, such as: Grid Search (searching the best hyperparameters using a
# grid of specified parameter values ); random search  (seeking the model
# with the optimal hyperparameters in a valid search space using a specified
# number of trials ); evolutionary algorithms  (finding optimal
# hyperparameters using heuristic-based approach es); and Bayesian
# optimization (a probabilistic model used for hyperparameters tuning).
# (iv) Model Evaluation: as discussed previously, the optimal predictive model
# is selected using various selection techniques, in which the performance
# can be measured on the training dataset. Yet, to study how the model
# generalizes on unseen dataset is another important consideration. This is a
# decisive step in the predictive modeling framework as it creates venues for
# continuous improvements on the implemented approach. In fact, building
# a robust predictive model is  not a trivial task; it entails carrying out solid6
# measures to quantify its effectiveness and accuracy. There are several
# metrics that can be used to evaluate the performance of a machine learning
# model. These measures can be mainly classified to two categories:
# Regression metrics and Classification metrics. Regression metrics include
# measures such: RMSE (Root Mean Square Error), MAE (Mean Absolute
# Error), R Squared (R²) and Adjusted R Squared . Classification metrics
# embody certain well-known metrics such as: Precision, Recall,  F1 Score
# Accuracy, ROC, AUC, Log-Loss etc.
# Stage 4- Integration and Visualization: Business Intelligence applications are
# designed mainly to process and manipulate structured data stored in data
# warehouses. Therefore, another significant task of predictive modeling framework
# is to articulate structure from unstructured input data. In thi s context, the data
# structuring process incorporate s semantic analysis so as to provide a better
# understanding of the schema structure of data warehouses. Thus, the next process
# will migrate these data with the data coming from the ETL (Extract, Transform and
# Load) process to produce integrated, meaningful, and trustworthy structured data to
# load into the integrated data warehouse. This integration of traditional business
# intelligence and social business intelligence will enhance the quality of reports
# extracted by BI tools, thus achieving an additional objective of the overall
# framework.7
#
# Figure 1: Predictive Analytics Framework for Social Big Data8
#
# 5.3 Machine learning algorithms for SBD
# predictive analytics
# In this section, we discuss several commonly used machine learning algorithms
# to develop a predictive model, which predicts the new social situation,
# ˆy , when the
# prediction features ,
# ( )12, ,..., nx x x x= , are given. The predictive model can be
# developed when a dataset which relating the prediction features and past social
# situation,
# y , is available, where
# n  is the number of prediction features. We discuss
# the following machine algorithms namely logistic regression (LR), generalized
# linear model, naïve bayes (NB), tree based classification, random forest , gradient
# boosted tree and deep learning:
# 5.3.1 Logistic Regression
# Logistic regression is a statistical method which has commonly been us ing for
# Similarity Score: 0.6099194288253784
# ================================================================================
# Chunk: Table 2: Quality measure of machine learning models
# Model Selection: There are plenty of ML models and introductory books on classical
# methods [45,79] and Deep Learning [72] can be used to compare and understand their char-
# acteristics. The model selection depends on the data and has to be tailored to the problem.
# There is no such model that performs the best on all problem classes (No Free Lunch Theorem
# for ML[80]). It is best practice to start with models of lower capacity, which can serve as
# baseline, and gradually increase the capacity. Validating each step assures its beneﬁt and avoid
# unnecessary complexity of the model.
# Incorporate domain knowledge:In practice, a specialized model for a speciﬁc task performs
# better than a general model for all possible tasks. However, adapting the model to a speciﬁc
# problem involves the risk of incorporating false assumption and could reduce the solution space
# to a non-optimal subset. Therefore, it is best practice to validate the incorporated domain
# knowledge in isolation against a baseline. Adding domain knowledge should always increase
# the quality of the model, otherwise, it should be removed to avoid false bias.
# Model training: The trained model depends on the learning problem and as such are
# tightly coupled. The learning problem contains anobjective, optimizer, regularization and
# cross-validation [45,72]. The objective of the learning problem depends on the application.
# Diﬀerent applications value diﬀerent aspects and have to be tweaked in alignment with the
# business success criteria. The objective is a proxy to evaluate the performance of the model.
# The optimizer deﬁnes the learning strategy and how to adapt the parameters of the model to
# improve the objective.Regularization which can be incorporated in the objective, optimizer
# and in the model itself is needed to reduce the risk of overﬁtting and can help to ﬁnd unique
# solutions. Cross-validation is performed for feature selection, to optimize the hyper-parameters
# of the model and to test its generalization property to unseen data [81]. Cross-validation11 of 20
# [45] is based on a splitting of historical data in training, validation and testing data, where
# the latter is used as a proxy for the target environment [82]. Frameworks such as Auto-ML
# [83,84] or Neural Architecture Search [85] enables to partly automatize the hyper-parameters
# optimization and the architecture search.
# Using unlabeled data and pre-trained models:Labeling data could be very expensive and
# might limit the available data set size. Unlabeled data might be exploited in the training
# process, e.g. by performing unsupervised pre-training [86,87] and semi-supervised learning
# algorithms [88,89]. Complementary,transfer learningcould be used to pre-train the network
# on a proxy data set (e.g. from simulations) that resembles the original data to extract common
# features [90].
# Model Compression:Compression or pruning methods could be used to obtain a more
# compact model. In kernel methods low rank approximations of the kernel matrix is an essential
# tool to tackle large scale learning problems [91,92]. Neural Networks use a diﬀerent approach
# [93] by either pruning the network weights [94] or applying a compression scheme on the
# network weights [95].
# Ensemble methods: Ensemble methods train multiple models to perform the decision
# based on the aggregate decisions of the individual models. The models could be of diﬀerent
# Similarity Score: 0.6066123843193054
# ================================================================================
# Chunk: Empirical learning curves are grown iteratively for the whole set or shrink-
# ing subsets of it. Successive halving and related works are a prominent
# example of horizontal decision making (Van den Bosch, 2004; Jamieson
# and Talwalkar, 2016). However, these approaches only consider the last
# anchor point (rather than the complete learning curve).
# 2. Vertical Model Selection. Vertical means that the set of learners is gener-
# ally not limited to a finite set, and the set of evaluated learner candidates
# evolves over time (i.e., not fixed apriori). Learners are evaluated one after
# another. Each learner is evaluated in an iterative fashion to grow a learn-
# ing curve and allow for early discarding. Examples are the early discarding
# routine for deep networks by Domhan et al (2015) or, more generally, for
# learning curve cross-validation (Mohr and van Rijn, 2021, 2023).
# 3. Diagonal Model Selection. This case is similar to the vertical decision-
# making situation with the difference that one does allow to continue the
# evaluation of a candidate at a later point. Hence, candidates are not
# evaluated one after another, but the evaluation of different candidates
# can be interleaved. Examples are Bayesian optimisation-based approaches
# to pause and continue evaluations of (not necessarily iterative) learn-
# ers (Klein et al, 2017a; Swersky et al, 2014). Non-iterative learners must
# be trained from scratch with the increased budget.
# Another approach that addresses this type of decision-making situa-
# tion is Hyperband (Li et al, 2017) and Bayesian optimisation based on
# progressive sampling (Zeng and Luo, 2017). However, neither of these
# approaches considers learning curves even though they implicitly con-
# struct them. Decisions are taken based on the observations of the largest
# anchor point considered so far.Springer Nature 2021 LATEX template
# 28 Learning Curves for Decision Making
# 4.2 Technical Questions Asked About Learning Curves
# A plethora of questions can be asked about learning curves. Fig. 10 gives an
# overview of these questions. The figure is organised in three layers (depth
# dimension) corresponding to the three types of estimates discussed in Sec. 3.
# Each layer consists of a set of questions that can be posed about learning
# curves. From bottom to top, the questions are ordered by complexity, and
# an arrow from one question to another indicates that the question with the
# incoming arrow is more general. Answering the more general question also
# implies answering the less general question.
# In the simplest case, we can answer a binary question. There are four
# relevant questions, i.e., (i) whether some specific anchor point, e.g., the dataset
# size, is beyond the saturation point (bsat ≤ bref ), (ii) whether the performance
# of a learner at the saturation point is better than some baseline τ (psat ≤
# τ), (iii) whether the performance pref := C(a, bref ) at some reference point
# bref is better than some threshold τ, or (iv) whether a specific anchor point
# is beyond the utility-based stopping point ( bu
# sat < bref ). To our knowledge,
# the only approaches in this category are those implicitly answering question
# (iii) by discarding candidates that are not believed to be competitive (see,
# e.g., Jamieson and Talwalkar, 2016; Petrak, 2000; Zeng and Luo, 2017); here
# τ = min a∈A C(a, bref ) is the (unknown) best performance of any learner on
# the target size.
# Similarity Score: 0.6057322025299072
# ================================================================================
# Chunk: applications of ML for SE in order to characterize the ob-
# tained articles into appropriate categories. We named the
# taxonomy as MLSE (machine learning for software engi-
# neering). The taxonomy was devised following the princi-
# ples mentioned in [51, 212]. As aforementioned, we have
# consultedtheknowledgeareasinSEfromtheSWEBOK[198]
# and envisioned a hierarchical-based classiﬁcation structure
# of the taxonomy. Each participant of the study analyzed the
# applicationsintheirassignedsetthearticlesandaggregated
# them based on the similarities as described in step 7 of Sec-
# tion 2.2. Subsequently, we have organized the applications
# of ML for SE as subbranches, which belong to ﬁve life cy-
# clestagesofSE(knowledgeareas). TheapplicationsofML
# for SE that come under corresponding SE life cycle stages
# along with the number of articles are brieﬂy explained be-
# low. Table 2 shows the corresponding articles with respect
# totheclassiﬁcationproposedasaMLSEtaxonomyasshown
# inFig. 5. Followingisa briefdescriptionof theelementsof
# the MLSE taxonomy:
# The Requirements stage comprises of three categories.
# • Requirements Modeling and Analysis (9 (4%) arti-
# cles): Requirement Modeling and Analysis contains
# articles that are focusing on distinguishing ambigu-
# ous requirements, resolving incompleteness, correct-
# ness of requirements, etc.
# Saad Shaﬁq et al.:Preprint submitted to Elsevier Page 5 of 20Machine Learning for Software Engineering: A Systematic Mapping
# Figure 3: Systematic Map - Association of Contribution/Research Facets with the SE Stage Facet
# Figure 4: Articles by SE life cycle Stages
# • RequirementsSelection/Prioritization/Classiﬁcation
# (6(3%)articles): RequirementsSelection/Prioritization/
# Classiﬁcation deals with articles proposing ML tech-
# niquesthatemphasizeonautomatingprioritizationof
# requirements or their classiﬁcation.
# • Requirements Traceability (6 (3%) articles):Re-
# quirements traceability contains articles that refer to
# theMLapproachesthatassistinlinkingrequirements
# to code or other artifacts.
# The Architecture and Design stage consists of three cat-
# egories.
# • Design Modeling (15 (7%) articles):Design Model-
# ing comprises of articles in which software process/
# servicesrecommendationmodelshavebeenproposed
# in order to facilitate the project managers in selection
# of the most suitable process model for their projects.
# Apart from this, model smells and re-factoring tech-
# niques of object-oriented structures using ML have
# also been proposed in the articles.
# • DesignPatternPrediction(4(2%)articles): Design
# Pattern Prediction comprises of articles that primar-
# ily focus on recognizing design patterns in software
# throughsourcecodeoruserinterfacelayoutusingML
# techniques.
# • Development Eﬀort Estimation (20 (9%) articles):
# Development Eﬀort Estimation refers to the eﬀort es-
# timation of software projects using ML techniques.
# The Implementation stage has four categories.
# • CodeClone/Localization/Re-factoring/Labelling(8
# (3%)articles): CodeClone/Localization/Re-factoring/
# Labellingcomprisesofarticlesthataimatﬁndingcode
# Similarity Score: 0.5926510691642761
# ================================================================================

# %% [markdown]
# # LLM Prompt Design

# %%
retrieved_chunks = " ".join(results["documents"][0])

prompt = f"""
You are a helpful scientific paper summarizer.
Summarize the following text in **200 words** based on this query: "{query}".

Text:
{retrieved_chunks}
"""

response = llm(prompt)
print(response)

# %% [markdown]
# # ChromaDB Function

# %%
def retrieve_chunks(query, top_k=5):
    query_embedding = embedding_model.encode(query).tolist()
    results = collection.query(
        query_embeddings=[query_embedding],
        n_results=top_k,
        include=["documents", "distances"]
    )
    
    chunks = results["documents"][0]
    similarities = [1 - d for d in results["distances"][0]]

    return list(zip(chunks, similarities))
